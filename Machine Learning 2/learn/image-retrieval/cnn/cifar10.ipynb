# %% [markdown]
# <a href="https://colab.research.google.com/github/AllanMogley/AllanMogley.github.io/blob/master/Machine%20Learning%202/learn/image-retrieval/cnn/cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/image-retrieval/cnn/cifar10.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/image-retrieval/cnn/cifar10.ipynb)

# %%
pip install datasets

# %%
from datasets import list_datasets, load_dataset
from pprint import pprint

# %%
datasets = list_datasets()
#list of datasets in pretty-print format
pprint(datasets, compact=True)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'tycru/autotrain-data-capture-the-flag', 'Nan-Do/code-search-net-go',
#  'wsapi/dset', 'Jokoasa/cagliostro-colab-ui', 'Garfieldgx/Js100',
#  'theoer/alpaca', 'd4niel92/celeb-identities', 'gycchris/gycchris', 'Fine/Lora',
#  'sngsfydy/DR_Grading_413_103', 'sngsfydy/Disease_Grading_for_DR_and_Mucula',
#  'yongchoooon/fire-test', 'databloom/smartmeterdata',
#  'Ashish08/celeb-identities', 'erfanzar/Data-Base-60K-1280',
#  'narugo/test_repo_20230513130444669194_812beb0367f3203641207e2b14c3b38dc8abf1e7',
#  'narugo/test_repo_20230513130517061226_f8bf92d9a139bc30f1494804e9161fb1cd8da3f7',
#  'narugo/test_repo_20230513132402445609_9cb568b4b399e55f2bac5b9fb3a13491048ef283',
#  'narugo/test_repo_20230513132403953173_d26a88a61da676b9e657ad24e2a250197b677e6a',
#  'narugo/test_repo_20230513132549310315_76d49c5df80dc5e9411eaa4ef50adb2703700564',
#  'tbensap18/KiriBeach', 'nouman-10/wikiart_testing', 'baira/indian_food_images',
#  'ugshanyu/jambal3', 'ugshanyu/jambal4', 'tbensap18/KiriTrash',
#  'bilal01/stamp-verification-test',
#  'narugo/test_repo_20230513145050466306_9c8d40d551cfece2e4f99a00b8d9fa88fdafa2a9',
#  'coyotespike/testdata', 'FASOXO/tianchi-stable-diffuiusion',
#  '0x22almostEvil/reasoning-gsm-qna-oa', 'guards/ONLY',
#  'polejowska/cd45rb_leukocytes_masks', 'Justiceak/yellow-book', 'izaiah/donver',
#  'Saberhaha/Saber', 'borjuft/borju', 'kaders/streaming',
#  'javilonso/rest23_sentiment_data_v2', 'Symato/CC_filter_demo', 'Zone369/Ai',
#  'zh-tw-llm-dv/zh-tw-pythia-a12k-alpaca', 'asikge/4KHD', 'tomemojo/questions',
#  'mesolitica/google-translate-lamini-lm', 'jiovine/pixel-art-nouns',
#  'biu-nlp/abstract-sim', 'Thaweewat/LaMini-instruction-th', 'sngsfydy/aptos',
#  'erichilarysmithsr/dovichousesimulation',
#  'erichilarysmithsr/autotrain-data-dovic-simulation-house-of-krebsville',
#  'Multimodal-Fatima/TextVQA_train', 'AIOVid/VidiX',
#  'adkenantiagingusa/Adken-Anti-Aging-Serum', 'nweras/sempolayam',
#  'Multimodal-Fatima/TextVQA_validation', 'Multimodal-Fatima/TextVQA_test',
#  'leostelon/happiness-report', 'annabely/ukiyoe_50_100_control_net',
#  'biu-nlp/abstract-sim-pubmed', 'annabely/ukiyoe_100_200_control_net',
#  'ewof/flan_unfiltered', 'seanghay/bookmebus-reviews', 'Dima31/1',
#  'JuanDie/sdsds', 'Saiteja/celeb-identities', 'hlky/lexica-aperture-v3',
#  'LucasThil/randomized_clean_miniwob_episodes_v2',
#  'Koyd111/llama-eng-jp-translation-captions', 'vost321/LExorciste23',
#  'plugnplai/plugins-dataset-sample', 'ttss/rdf-triple-based-summarization',
#  'cjensen/celeb-identities', 'swadesh7/telugu_train_labelled',
#  'swadesh7/telugu_test_labelled', 'marasama/nva-aoi_sakura',
#  'marasama/nva-sill', 'sultan93/ar_bactarian',
#  'danielv835/personal_finance_v0.2', 'scaredmeow/shopee-reviews-tl-stars',
#  'marasama/nva-Escalayer', 'DeadBeast/dreambooth-images',
#  'hostiliann/ererererer', 'jiovine/pixel-art-nouns-2k', 'sejalg/blur_caption',
#  'AlekseyKorshuk/roberta-no-topic-predictions', 'romaye/oliverr',
#  'CVasNLPExperiments/VQAv2_test_no_image_google_flan_t5_xl_mode_A_T_D_PNP_FILTER_C_Q_rices_ns_100',
#  'tatsu-lab/alpaca_farm', 'AlekseyKorshuk/reward-model-no-topic-predictions',
#  'cemcoe/xiaoqunqun_data_set', 'johnwick123forevr/ImageCaptioningDataset',
#  'Cacau/drkiridescentrealm', 'obrito/celeb-identities',
#  'falbanese/community-changing-users', 'kartik727/Test_Dataset',
#  'wisewizer/sample-dataset', 'uselessbug/svc_dataset',
#  'jeevavijay10/senti-pred-gradio', 'kevincluo/celeb-identities',
#  'Nan-Do/code-search-net-python', 'moyebir/kapooran', 'sameer7/sample-data',
#  'CVasNLPExperiments/VQAv2_validation_no_image_google_flan_t5_xxl_mode_A_T_D_PNP_FILTER_C_Q_rices_ns_2000',
#  'ramgus/musicdiffuser',
#  'CVasNLPExperiments/VQAv2_validation_no_image_google_flan_t5_xxl_mode_T_A_D_PNP_FILTER_C_Q_rices_ns_2000',
#  'jobiral/gimy',
#  'CVasNLPExperiments/VQAv2_test_no_image_google_flan_t5_xxl_mode_T_A_D_PNP_FILTER_C_Q_rices_ns_1000',
#  'vg055/analisis-sentimientos-textos-turisitcos-mx-polaridad-DataAugmentationV1',
#  'containerlib/embedded_sg_faq', 'khelton/celeb-identities',
#  'annabely/ukiyoe_10_30_control_net', 'deman539/celeb-identities-test',
#  'wuyetao/spp', 'yuyang/distil_xsum', 'ramgus/albumcovers',
#  'Nan-Do/code-search-net-javascript', 'Thouph/dump_complete',
#  'amiestone65/Up-DOWN', 'zxzl/celeb-identities', 'gempuling/123abc',
#  'blastwind/github-code-haskell-function', 'blastwind/github-code-haskell',
#  'caseyellison611/caseyellison611', 'kudusabar28/kudusabar28', 'ACCname/chat',
#  'Phuoth/6e-complete',
#  'TeamSODA/ae-signal_processing_attacks_whisper_librispeech',
#  'theodoremichael62/theodoremichael62', 'nanxstats/movie-poster-5k',
#  'Zerenidel/Re_Hamatora_Nocaption', 'pxovela/merab_6_longer_adjusted_captions',
#  'sushmanth/cells', 'Sey24/seylora', 'Vanmas/PoE_data',
#  'pxovela/training_setting_burnt_unet_and_text_encoder',
#  'TeamSODA/cl-signal_processing_attacks_whisper_librispeech', 'inx38/emd',
#  'keplatok/humxyz', 'FanChen0116/restaurant8k_full_10000syn_merged',
#  'darksensei/details_dataset', 'WasuratS/ECMWF_Thailand_Land_Air_Temperatures',
#  'Gae8J/gaepago_s', 'SilpaCS/Ecommerce', 'spooninc/test',
#  'Ruqoyya/celeb-identities', 'ramgus/albumcoverswithcaptions', 'chebao/rv',
#  'FanChen0116/restaurant8k_full_10000syn', 'Pranavkpba2000/skin_cancer_dataset',
#  'digenjor/aq123', 'pxovela/Test_Images_Overtrained_TE_vs_Unet',
#  'WeixuanYuan/VAE_sound', 'erfanzar/Data-LGeM-60K', 'Fine/Embedding',
#  'Fine/Stable-diffusion', 'polejowska/NCT-CRC-HE-45k',
#  'cdminix/libritts-aligned', 'Alisairlines/SentimentA', 'nightaway/pixelart',
#  'ramgus/albumcoversfinal', 'diffusers/prompt_generations', 'useruser1/jkk',
#  'Nikinzt/medical-gen-vqa', 'breadlicker45/music-whisper-dataset',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta1k-f6dd50-embeddings-tr_alp-61d3e1-c2048',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-f6dd50-embeddings-tr_alp-61d3e1-c2048',
#  'Englishman2022/prosocial-dialog-filtered', 'trappy/olisyoyolisolora',
#  'diffusers-parti-prompts/sd-v1-5', 'edangx100/celeb-identities',
#  '0x22almostEvil/russe-semantics-sim', 'Nan-Do/code-search-net-php',
#  'tasksource/starcon', 'Naoki3/nva-maid',
#  'bjoernp/1-sentence-level-gutenberg-en_arxiv_pubmed_soda', 'ppisljar/test',
#  'darknoon/noto-emoji-vector-512-svg',
#  'vg055/RestMex2023_review-corpus_DataAugV1', 'polejowska/CRC-VAL-HE-7K',
#  'wyp/cblue-mrg', 'JoffreyMa/BGDIA704_faces', 'Nan-Do/code-search-net-ruby',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr_alp-69ed82-c2048',
#  'Sybil-Vane/Test', 'diffusers-parti-prompts/sd-v2.1',
#  'dembandoye/fakedocuments_version_1', 'switmer/MBTI-Sentiment',
#  'scaredmeow/shopee-reviews-tl-binary', 'diffusers-parti-prompts/if-v-1.0',
#  'zera09/Test', 'akorson/AKINTHECHI', 'bilal01/stamp-verification',
#  'javilonso/rest23_sentiment_data_v3_oversampling', 'clueless/asvspoof2021',
#  'carlosejimenez/seq2seq-glue', 'Clown17/sd_configs',
#  'henryscheible/coco_val2014_tiny', 'Serum/for_sd', 'talanAI/resumesamples',
#  'jurnu/viajaratenerife', 'jurnu/df', 'jurnu/f', 'jurnu/m', 'jurnu/d',
#  'Ggbg/Lelothehero', 'Multimodal-Fatima/VQAv2_testdev_final',
#  'edarchimbaud/index-constituents-sp500', 'Multimodal-Fatima/VQAv2_testdev',
#  'spooninc/test2', 'Mjarrin/ridge2', 'cvtlyp/controlnet_ap10k_resized_v3',
#  'Mjarrin/ridge3', 'Mjarrin/ridge4', 'Mjarrin/ridge5',
#  'diffusers-parti-prompts/karlo-v1', 'Mjarrin/ridge6', 'Mjarrin/ridge7',
#  'Mjarrin/ridge8', 'Mjarrin/ridge9', 'Mjarrin/ridge10', 'Zhoucai/RobertFrost',
#  'Sharka/SQAD_VQA', 'Dampish/Eval_STELLAR', 'Sharka/SQuAD_VQA',
#  'Multimodal-Fatima/VQAv2_testdev_no_image', 'parvezalmuqtadir/dataset',
#  'CVasNLPExperiments/VQAv2_testdev_no_image_google_flan_t5_xxl_mode_T_A_D_PNP_FILTER_C_Q_rices_ns_1000',
#  'dmayhem93/self-critiquing-base-topic-embeddings', 'Dampish/EVAL_STELLAR2',
#  'younyokel/CyclopsModel', 'silk-road/Wizard-LM-Chinese-instruct-evol',
#  'dmayhem93/self-critiquing-base-selected-900',
#  'andersonbcdefg/rp_1b_tokenized', 'MungunshagaiT/coursera-reviews',
#  'MungunshagaiT/coursera-review-label-3', 'qiaokuoyuan/sickid-to-sickname',
#  'marasama/nva-ajax2', 'tgokhale/sr2d_visor', 'marasama/nva-Narika_Shihoudou',
#  'sdasdadas/stolen_RVC',
#  'CVasNLPExperiments/VQAv2_testdev_no_image_google_flan_t5_xl_mode_T_A_D_PNP_FILTER_C_Q_rices_ns_1000',
#  'dop13/ass', 'Gdot/clts', 'benzzuu/your-dataset-name',
#  'marasama/nva-IzawaRitsuko', 'vg055/RestMex2023_review-corpus_DataAugV2',
#  'adelavega/dominoes',
#  'CVasNLPExperiments/VQAv2_testdev_no_image_google_flan_t5_xl_mode_T_A_D_PNP_FILTER_C_Q_rices_ns_107394',
#  'talanAI/jobpostingsamples', 'chenyanjin/legedo-github-issues', 'dop13/a',
#  'kmlin/fangyi', 'daitavan/financial-documents', 'shyamsankeerth/dataset1',
#  'aadik1ng/sisley', 'Lxm001/webui_env', 'aquamansam/Shrekfest',
#  'vg055/RestMex2023_unsupervized-corpus_DataAugV2', 'sedc/snowraven',
#  'yarkovat/ganzerfilm', 'Defalt-404/Bittensor_relative_QA',
#  'silk-road/MMC4-130k-image-english', 'Jcoderdev/dicas-investimentos',
#  'hongerzh/NFT', 'zzzzzy/zy', 'silk-road/Luotuo-QA-A-CoQA-Chinese',
#  'Lxm001/001',
#  'CVasNLPExperiments/VQAv2_testdev_no_image_google_flan_t5_xxl_mode_T_A_D_PNP_FILTER_C_Q_rices_ns_107394',
#  'xiazeyu/DT_SegNet', 'huepuru/testus2', 'Lxm001/config',
#  'dspoka/ccai-nlp-tutorial-1', 'lighteval/MetadataTableTest', 'sedc/blackwhite',
#  'Sid103/Covid23', 'hundredeuk2/ranking_data',
#  'skinbiotixmdskintag/SkinBiotix-MD-Skin-Tag-Remover', 'shangyou/1',
#  'germank/shp_with_features_20k_flan_t5_large', 'jarrydmartinx/metabric',
#  'jarrydmartinx/support', 'jarrydmartinx/deepsurv_gbsg', 'ACCA225/sdconfig',
#  'junliu44/code_subset', 'dexforint/my_cats', 'manjunath-lalith/olm-wiki',
#  'jarrydmartinx/nwtco', 'banloada/ban', 'guo1109/11111',
#  'alfapowertabletta/alfapowertabletta', 'bene-ges/en_cmudict',
#  'alfapowertabletta/alfapower1', 'catslovedata/testdata1',
#  'alfapowertabletta/alfapower', 'alfapowertabletta/Alfa12Power', 'apsys/WCS',
#  'bjoernp/gaps_fr', 'jm4n21/CR', 'dgblife/detection_clp',
#  'davanstrien/cards20230512', 'ricecake/PreinstalledSD',
#  'pytorch-survival/metabric', 'pytorch-survival/flchain',
#  'pytorch-survival/support', 'pytorch-survival/rotterdam_gbsg',
#  'pytorch-survival/nwtco', 'Ranjan22/Medium_Articles',
#  'StivenLancheros/en_xwikis_processed', 'mareed/kriiikkk',
#  'flagship/thermal-dgan', 'glucotrustprecio/glucotrustprecio',
#  'kotarodayo1126/dejiko', 'glucotrustprecio/glucotrustbeneficios',
#  'brycegreened/ye', 'Haroldf01/InvoiceData',
#  'glucotrustprecio/glucotrustparaquesirve',
#  'glucotrustprecio/glucotrustcomentarios', 'glucotrustprecio/glucotrustquees',
#  'glucotrustprecio/capsulasdeglucotrust', 'SkinBiotixMDus/SkinBiotixMDus',
#  'glucotrustprecio/pastillasdeglucotrust',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/c840440e',
#  'piyushsaxena5494/autotrain-data-aaset-bert-qna', 'deepghs/nsfw_detect',
#  'semenaxerfahrung/SemenaxErfahrung', 'semenaxerfahrung/Semenax',
#  'semenaxerfahrung/SemenaxBewertungen', 'Leejk/121212',
#  'Wanghaifeng68/earthquake', 'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/1245832e',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/d6b9c357', 'and-effect/MDK_taxonomy',
#  'SotiriosKastanas/groto', 'VSDEV/QOUTES', 'liliy/123456',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/f8ebda26',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/b5cf07b3',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/6c06c658', 'qwq233/zzj',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/7254e21f',
#  'skinbiotixmdskintagserum/SkinBiotix-MD-Skin-Tag-Remover', 'onmov/remon',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/1085a5b6',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/0840a30b',
#  'ewof/lamini-instruct-unfiltered-deduped', 'yulanfmy/databricks-qa-ja',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/d690e2ac',
#  'BasSabretooth/amongstotherthings',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/deec2759', 'kawaiimaid55/shoeslearn',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/ebc52d2b',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/747e7d53', 'g4m3r/LS23',
#  'P829692/best-model', 'vg055/RestMex2023_unsupervized-corpus_DataAugV3',
#  'vg055/analisis-sentimientos-textos-turisitcos-mx-polaridadV3-DA',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/f2585c11',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/d025b660', 'hyn/test-github-issues',
#  'helezabi/fcb_scan', 'Kutsuya/SinonVoice', 'HemangJoshi/Chatbot',
#  'prompthero-diffusion-models/Lighting-For-ControlNet',
#  'PaulineSanchez/Multi_restaurants_menus_translation',
#  'OdiaGenAI/hardcode_odia_qa_105', 'Squish42/bluemoon-fandom-1-1-rp-cleaned',
#  'luximuwy/proxzy', 'PaulineSanchez/dataset_food_translation_v2',
#  'davanstrien/testmodelcardwdata',
#  'Shaharb/us-social-security-medicare-FAQs-test',
#  'PaulineSanchez/Dataset_food_translation_fr_en', 'nixyjuhi/ewapoz',
#  'adi789/nba', 'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/0ca7bb7b',
#  'Kasuzu/Laboral_db', 'ramgus/audiofeaturesalbumcovers',
#  'arubenruben/portuguese_xlsum', 'h2oai/db_dirs',
#  'medmac01/qa_morocco_history_v1', 'markbotterill/test_dataset',
#  'woxine/appbiz', 'Cacau/daedraport', 'Yamei/TVCG_NER', 'bene-ges/en_gtn_vocab',
#  'HK83/Anime', 'ernestum/TestDataset', 'edarchimbaud/timeseries-daily-sp500',
#  'conceptofmind/flan_dialog_submix_original_8k_neox_pad',
#  'conceptofmind/flan_cot_submix_original_8k_neox_pad',
#  'smithr14buckeye/whistlingflagsdataset',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/b47a6b0d',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/a87bd4e2', 'Linconabe/tarzan1999',
#  'yagac/HollyKnight', 'wangweizhi98/FLAIR',
#  'conceptofmind/flan_niv2_submix_original_8k_neox_pad', 'rajaneeshr/deta',
#  'lucasmccabe-lmi/FLAN_CoT_alpaca_style', 'Kelish/Omkar',
#  'pranjali97/covid-qa-set', 'torchgeo/ssl4eo-downstream',
#  'juancopi81/lmd_clean_8bars_32th_resolution', 'pranjali97/covid-qa',
#  'sam-liu-lmi/databricks-dolly-15k-alpaca-style', 'fcdufycv8yivy/random_code',
#  'c-s-ale/english_to_pirate', 'Finnish-NLP/mc4_3.1.0_fi_cleaned',
#  'factored/fr-crawler-private',
#  'conceptofmind/flan_flan2021_submix_original_8k_neox_pad',
#  'OMazzuzi90/Ita2Sql_data_train_small',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/e6ed0e01', 'Ar4ikov/resd_ref',
#  'HK83/Anime_Faces', 'fraisdufour/templates-verbs',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/18ae53b8',
#  'winglian/chatlogs-en-cleaned', 'Katrg/Kafka-HonkaiStarRail',
#  'javilonso/restmex23-test', 'OdiaGenAI/all_combined_odia_171k',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/52473874',
#  'SamaAI/sama-drives-california', 'akufeldt/covid_qa_ak_203',
#  'ramgus/audiofeatures2albumcovers', 'pytorch-survival/kkbox',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/c961a6e2',
#  'conceptofmind/python_stack_8k_neox', 'Miuno/My_falling_set', 'pldb/PLDB',
#  'bollboll9/your-dataset-name', 'higart/LoRA_models', 'gonglinyuan/CoSQA',
#  'AmazonScience/tydi-as2', 'AmazonScience/xtr-wiki_qa', 'Energystar/Mikmaq',
#  'bri25yu/flores200_devtest_translation_pairs',
#  'Astonzzh/summary_seq_label_more_splits', 'deedax/UTK-Face-Revised',
#  'ceval/ceval-exam', 'zuizui/jenna',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/d7749d15',
#  'duyduong9htv/celeb-identities', 'jarm1988ainhoa/NOME_DO_SEU_DATASET-train',
#  'jarm1988ainhoa/NOME_DO_SEU_DATASET-valid', 'purplehaze1/CrowdHuman',
#  'jarm1988ainhoa/Training_Transformers_INF2032-Txt',
#  'mesolitica/crawl-carigold', 'daisr/my_test_dataset1',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/62de9313', 'ning0ing/test',
#  'MexFoundation/google_maps', 'sdasdadas/stolen_SVT',
#  'silk-road/MMC4-130k-chinese-image', 'ramonpzg/latin_music',
#  'PeterPanTheGenius/WISE1', 'Cofacts/line-msg-fact-check-tw', 'liwymy/xfast',
#  'liwymy/xfastx', 'JaclynGu/HoyFieldWindow', 'liwymy/streeat22', 'liwymy/gsdaz',
#  'ianeaton178/rodrim', 'unlimitedbananas/second-model-our-captions',
#  'SIAKAM/jubao_finetune', 'hwchalmers/MomentumII',
#  'bitcoin360ai/bitcoin360aierfahrungen',
#  'lirus18/deepfashion_with_captions_blowout', 'bitcoin360ai/bit2.0avaprobot',
#  'bitcoin360ai/bit2.0avapro', 'bitcoin360ai/bitcoin360aibewertungen',
#  'bitcoin360ai/bitcoin360aiforum', 'annuo/wxcutout_controlnet_1k',
#  'claudettecarey/onikx', 'FreedomIntelligence/ShareGPT-CN',
#  'FanChen0116/syn_full_all_merged_empty', 'mozilla-foundation/youtube_regrets',
#  'Chaymaa/ufpr-amr-donut', 'aimingter/model-2-2.5D',
#  'ramgus/albumcoversongtitle', 'Fuckoff12/Excelll', 'Creed3/Steven',
#  'resumen/peliculas', 'Hemanth-thunder/en_ta', 'Sulukumarpatti/sulumarpattiout',
#  'bene-ges/spellmapper_en_evaluation', 'gisu/nva_desuko',
#  'alexwww94/datasets-for-simcse', 'lansinuote/diffusion.8.instruct_pix2pix',
#  'unklefedor/language-identification', 'GiorgiSekhniashvili/common_voice_13_0',
#  'rajc111/xpertreviews', 'bosnakdev/turkishReviews-ds-mini',
#  'truongc63/lamyennhi_v1', 'ShreyasBrill/Vercuna-Dataset', 'aimingter/vae',
#  'lighteval/mmlu', 'bjoernp/gaps_it', 'darrenwatkins39/darrenwatkins36',
#  'it-at-m/LHM-Dienstleistungen-Corpus', 'JosephusCheung/GuanacoVideoQA',
#  'llm-book/livedoor-news-corpus', 'Laurie/alpaca_chinese_dataset',
#  'omniquad/BC5CDR-IOB', 'ucang/OJSADJ', 'omniquad/BioNLP11ID-ggp-IOB',
#  'J-Mourad/MNAD_Sample', 'carebellisimabitesgummies/BellisimaBitesGummies',
#  'markbotterill/olist_encoded', 'Pranavkpba2000/skin_cancer_small_dataset',
#  'center-for-humans-and-machines/style-diffusion',
#  'minoosh/IEMOCAP_Text_dataset', 'bjoernp/gaps_de',
#  'minoosh/IEMOCAP_Speech_dataset', 'Xynoz/cagliostro-colab-ui',
#  'J-Mourad/MNAD.v1', 'J-Mourad/MNAD.v2', 'ligaseng49/ligaseng48',
#  'Multimodal-Fatima/VQAv2_minival_no_image', 'Proverb/medicare',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_T_Q_rices_ns_25994',
#  'Oharawebsite/diary',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_T_A_Q_rices_ns_25994',
#  'GlucoFreezeOfficial/GlucoFreezeOfficial', 'chilge/ddsp',
#  'Ryan1122/multiturn_cn_18k', 'Lfr111/cv-data', 'Dinesh007a/new_sampl_rev_data',
#  'zzc0208/srvits', 'getbellisimabitesgummies/BellisimaBitesGummies',
#  'macsoftwaresolutions/psttoolmconverter', 'sidovic/squad_arabic',
#  'hauptmann/conceptnet_numberbatch_19_08_ger',
#  'mewsakul/test-project-brand-story-gen-test', 'rmk123/dataset_1',
#  'kobkrit/rd-taxqa', 'zeroshot/cybersecurity-corpus', 'cakiki/roots-tsne-data',
#  'harineemira/dataset',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_A_Q_rices_ns_25994',
#  'Neidhardt/testing-1', 'wyp/cblue-cdn', 'mpajas/hotel-dataset',
#  'hauptmann/fasttext_ger', 'narizhny/addresses-2',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_T_A_D_PNP_FILTER_Q_rices_ns_25994',
#  'hauptmann/glove_ger', 'narizhny/addresses-3',
#  'Fredithefish/Instruction-Tuning-with-GPT-4-RedPajama-Chat',
#  'ltg/chat-nort5-logs', 'TrainThenObtain-ai/Utra-mini-GPT-4',
#  'dtldhjh/github-issues',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_D_PNP_FILTER_Q_rices_ns_25994',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_C_Q_rices_ns_25994',
#  'OOPPEENN/Oyama_Mahiro', 'TMZN/lunyu',
#  'StivenLancheros/xwikis-augmented-processed',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_D_PNP_FILTER_C_Q_rices_ns_25994',
#  'valashir/SMM2-levels-final', 'ramgus/fullalbumcovers',
#  'valashir/SMM2-levels-all', 'hdparmar/trail-spectrogram-dataset',
#  'praveendaseugene/demo1',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_A_D_PNP_FILTER_C_Q_rices_ns_25994',
#  'Trismegestus/BizarreDilemma', 'narizhny/test',
#  'openllmplayground/pandagpt_visual_instruction_dataset', 'legendur/cungcay',
#  'err604/silkt-dataset',
#  'CVasNLPExperiments/VQAv2_minival_no_image_google_flan_t5_xl_mode_T_D_PNP_FILTER_C_Q_rices_ns_25994',
#  'RandomCatLover/logs_for_demo_nlp',
#  'orderofmagnitude/eValuation_Tommie_Dataset_Context',
#  'JasperLS/prompt-injections', 'ReehaKhan/CSR',
#  'hlillemark/flores200_devtest_mt5-600m-flores200-scaffold',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/b5848c29',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/a343deba', 'santimotolo/myketowers',
#  'albanc/autotrain-data-doodles-30',
#  'hlillemark/flores200_devtest_translation_pairs_mt5', 'Zerenidel/SquadLogo',
#  'agestau/preproc-fashion-products',
#  'cimadure/snow_removal_transactions_in_montreal',
#  'FanChen0116/only_syn_full_all_merged',
#  'christinacdl/offensive_language_greek', 'escottyp/celeb-identities',
#  'evanhelga/sazarita', 'vincha77/english_to_pirate',
#  'Neu256/arc-diffusion-dataset-1', 'Finnish-NLP/wikipedia_20230501_fi',
#  'osunlp/AttrScore', 'dharcness/helltaker', 'zetavg/ShareGPT-Processed',
#  'Finnish-NLP/wikipedia_20230501_fi_cleaned', 'vjain/psych',
#  'mlfoundations/datacomp_indices', 'alansun25/cs375_cv11_mandarin_train',
#  'mvasiliniuc/iva-swift-codeint-clean-train',
#  'alansun25/cs375_cv11_mandarin_test',
#  'mvasiliniuc/iva-swift-codeint-clean-valid', 'TREC-AToMiC/AToMiC-Baselines',
#  'alansun25/cs375_cv11_mandarin_dev', 'Spelo/SnowFox-Data', 'Dadams2244/Test',
#  'emanuelebezzecchi/trailerShotScale', 'vjain/Therapy',
#  'nelson2424/FAQ_NelsMarketplace', 'bollboll9/bri',
#  'benlehrburger/modern-architecture', 'mrkhanna/covidqa',
#  'tomaszes19/test-model', 'mehmetadventlabs/secim2023-cb-partial',
#  'Sree1994/covidqa_copy', '25-jiHiorns/madeby-Hio',
#  'LucasThil/randomized_clean_miniwob_episodes__image0_5000_v2',
#  'ThomasBaruzier/wikipedia', 'citruschao/revision_comment_intent',
#  'citruschao/revision_comment_intent2', 'takeraparterer/stinky-heap',
#  'sambanovasystems/xOA22', 'tonarie/Wayback-Data-Youtube-Homepage-Videos',
#  'winglian/evals', 'Cheltone/COVID_Twitter_Reddit_Jan2020_Feb2022',
#  'sambanovasystems/x-self-instruct-seed-32',
#  'FreedomIntelligence/huatuo26M-testdatasets', 'scaredmeow/hatespeech-for-demo',
#  'manh-linh/dataset1', 'sayaka0707/Nanami_Chiaki',
#  'daniilturpitka/Pierre_Baldi_Voice_Set', 'sdasdadas/mei3',
#  'ai4bharat/Bhasha-Abhijnaanam', 'shrusti333/konkani_translation',
#  'AlekseyKorshuk/hh-lmgym-demo', 'aravind-selvam/chart_data',
#  'lakefuha/HalIr10', 'explodinggradients/ragas-webgpt', 'MrHaiPi/DPV',
#  'dongwoojung/flan_t5_qna', 'misuty/srbmax', 'nikes64/ualpaca-gpt4',
#  'marasama/nva-mylene_rafa_holfort', 'insly/language', 'halowaqer/atmovies',
#  'humzaasahe/online', 'Frewob/cinemas', 'CarlosKidman/test-cases',
#  'shthom2004/onlinefilm', 'umarzein/databricks-dolly-15k-en',
#  'lansinuote/simple_facenet', 'MoCe/optimized-sd-config',
#  'shi3z/alpaca_cleaned_ja_json', 'bjoernp/gaps_spa', 'kilyga/RomLaz',
#  'nc33/test_qa', 'mitathin/MitaThin', 'JisuofthePark/UNEEK_ESL',
#  'LudditeDrawslave/cookies', 'tikaje/AloMzo', 'UYio/jokza', 'pauri32/fiqa-2018',
#  'lirus18/deepfashion_with_captions_blowout_stacked', 'taten/yesmovv',
#  'bperel/inducks-covers', 'archxin111/111', 'scofieldlin/scofieldlin_test',
#  'safetensors/assets', 'Alasty/test_image_cc_sbu_align',
#  'G12345/sidewalk-imagery16', 'Jumtra/for_finetune_mpt7b',
#  'hofarah/long-persian-summarization-beta',
#  'phamson02/vietnamese-poetry-corpus', 'G12345/sidewalk-imagery17',
#  'Jumtra/dolly_oast_jglue_ja', 'AchrafLou/achraf-ds',
#  'hlillemark/flores200_devtest_mt5-600m-flores200-baseline',
#  'AchrafLou/image_captioned', 'gamapsh/FIM_CNET_Wrapped',
#  'Flooki10/autotrain-data-pr_final_covid-19', 'mitathinnews/MITATHIN',
#  'sivan22/hebrew-words-dataset', 'JaclynGu/2Hoys1Balcony',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr__alp-cd978d-c2048',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr__alp-a1a0fd-c2048',
#  'wellgardapplecidervinegar/WellgardAppleCiderVinegarGummies',
#  'wellgardapplecidervinegar/WellgardAppleCiderVinegarGummiesforWeightLoss',
#  'wellgardapplecidervinegar/WellgardAppleCiderVinegarGummiesReview',
#  'wellgardapplecidervinegar/WellgardAppleCiderVinegarGummiesUK',
#  'wellgardapplecidervinegar/WellgardVeganAppleCiderVinegarGummies',
#  'AchrafLou/image_captionedd', 'shevchenkoms/test',
#  'AchrafLou/image_captioneddd', 'jerma66/TGEA2.0', 'aalksii/ml-arxiv-papers',
#  'aignosi/langchaing-docs-chatgpt-plugin', 'scofieldlin/scofieldlin_1',
#  'OpenDungeon/CRD3-prerpocessed', 'MitaThinOfficial/MitaThinOfficial',
#  'MitaThinReviews/MitaThin',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr_wiki_sg_alp-f36645-c2048',
#  'hdparmar/specdata', 'Neekey/test_datase', 'husangui/majicMIXrealisticV2',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/10a6ef7d', 'raygx/NepCov19Tweets',
#  'LinZhao/LLaVA-Instruct-21K-COCO-SubSet',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/0f9134d7', 'alzoubi36/privaseer_demo',
#  'open-source-metrics/safetensors-dependents', 'jsdoradea/Intermedia3',
#  'sno0owing/kitti_seg', 'deepset/prompt-injections',
#  'tanupriyasingh1234/celeb-identities', 'yangwang825/reuters-21578',
#  'TMZN/quantangshi', 'MattiaL/tapir-cleaned-top90', 'nixxon/nixxon',
#  'FanChen0116/restaurant8k_64_new', 'cdsi-nlp-workshops/arxiv_classification',
#  'wangrongsheng/Huatuo-data', 'wangrongsheng/Huatuo-liver-cancer',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/a01758e5', 'KaraAgroAI/CADI-AI',
#  '0x22almostEvil/ws-semantics-simnrel', 'tvmalaysiaorg/TV6-Live',
#  'Sunbird/chrf-referenceless-salt-train', 'alzoubi36/privaseer',
#  'GIL-UNAM/TwitterHappiness', 'casual/national_speech_corpusv2',
#  'hlillemark/flores200_devtest_mt5-600m-flores200-packed',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/37dd4157',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/720c5d3f',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/c852cf92',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/2f97018c', 'deu05232/train',
#  'deu05232/test', 'laurenmit/project_7_dataset_1500', 'rjacquemin/tests-song',
#  'dominguesm/tedx-ptbr', 'AlekseyKorshuk/chai-examples', 'Fine/isekaijou',
#  'Pratha1m/dataset_with_ocr', 'hlillemark/c4_t5',
#  'skeskinen/TinyStories-Instruct-hf', 'Braddy/rsicd_deduplicate_97',
#  'edarchimbaud/news-sp500', 'skeskinen/TinyStories-hf',
#  'OMazzuzi90/Ita2Sql_data_train_Helsinki', 'Braddy/rsicd_deduplicate_99',
#  'bjoernp/translation_de_en_wgaps_250Mtokens',
#  'FanChen0116/restaurant8k_64_new_empty', 'Braddy/rsicd_deduplicate_95',
#  'FanChen0116/syn_few7_0511_4_5600data', 'lirus18/fill50k',
#  'FanChen0116/syn_few7_0511_4_5600data_empty', 'zadhart/PlantsChatbotPTBR',
#  'bjoernp/wiki_de_250Mtokens', 'gamapsh/test', 'fuzzbin/euler',
#  'EveryPizza/autotrain-data-imagetest', 'Koyd111/alpaca-jp-eng',
#  'xekri/audio_letters_eo', 'yangwang825/marc-ja',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr_wiki_sg_alp-c6795a-c2048',
#  'purav/animals',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr_wiki_sg_alp-396867-c2048',
#  'genta-tech/GoogleNaturalQuestion_Indo', 'dhmeltzer/ELI5_embedded',
#  'Fraol/Py150-processed', 'cedwin/log_c',
#  'zh-tw-llm-dv-dv/zh-tw-llm-dev-sample-ta8k-d40d11-only_embeddings-tr_wiki_sg_alp-c17ba7-c2048',
#  'GeanM/Noticias', 'Rajjjj/SSM', 'marasama/nva-dog',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/aac4766c',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/b29e2786', 'CrowdAILab/scicap',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/0f1659c6',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/2c4acff4',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/44212031', 'mrsteyk/opechatgpt-safe-r1',
#  'devsamlak/chat-creator', 'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/28ac5cf1',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/3de4ad84', 'OpenGenAI/logos',
#  'mrsteyk/openchatgpt-safe-r2', 'GorkemPolat/LIMUC',
#  'linhtran92/deduplicated_dataset_400hrs_wer0', 'mooncakex/arts',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/a4419c50', 'qntm/shrink',
#  'ReehaKhan/AlpacaTraining', 'ReehaKhan/AlpacaTesting', 'makilza/bizdulonline',
#  'yangwang825/tnews', 'shreevigneshs/capstone-eng-hau-unclean-train-valid-0.1',
#  'KyonBS/AdultNishikata', 'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/1706e1cd',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/28d5d641',
#  'cj-mills/hagrid-classification-512p-no-gesture-150k',
#  'Yuchong/us-breast-cancer', 'vjain/Gurbani',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-001', 'gafija/kucbhung',
#  'yangwang825/klue-ynat', 'Yuchong/us-liver', 'Yuchong/us-vessel',
#  'erkam/clevr-full-v3', 'Yuchong/endo_instrument', 'Yuchong/endo_ployp',
#  'ianel/lora', 'vectominist/spin_data', 'ProjectFisokuhle/aws_lambda',
#  'bleugreen/typescript-chunks', 'ianel/lora2', 'xiemoxiaoshaso/xiemoloras',
#  'zcv/test3', 'RengJEY/Fast_Food_classification',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/e07e0041', 'vectominist/spin_ckpt',
#  'elitehacker/indo9mill.rar', 'sled-umich/MindCraft',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/dbd31000',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/fa1be0f1', 'xiemoxiaoshaso/ceshi',
#  'JosueN/e', 'robbiezimmer/VeVX', 'vietgpt/hieunguyen_news_vi',
#  'xmj2002/genshin_ch_10npc', 'baghong/hulkingset',
#  'ledboot/stable-diffusion-res', 'yacahu/train_model',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/e4f0cd73', 'maxisza/onlinebuzzta',
#  'valashir/SMM2-levels-simple', 'vishnuramov/ITU-T-Build-a-thon',
#  'Haziqsayyed/gpt-expressions', 'gilangsiregare/allovx', 'zmeanszachary/ipl',
#  'baike33/pokemon-add-logo', 'PocketDoc/QED-Alpaca',
#  'fujiki/japanese_alpaca_data', 'zmeanszachary/ipl1',
#  'averageandyyy/train_librispeech_self', 'yangdechuan/demo',
#  'jiawei1998/metaner-pretraindata', 'joeySadventure/dataset_pokemon',
#  'Travad98/SOGC-archive-trademarks-1883-2001', 'zmeanszachary/adad',
#  'averageandyyy/combined_librispeech_self', 'thewall/tg2', 'emmadrex/emmadrex',
#  'feier88/yunka', 'sulisdayik/flodew', 'Eitanli/goodreads',
#  'mitermix/chess-selfplay',
#  'hlillemark/flores200_devtest_mt5-1b-flores200-scaffold', 'qqdwx/moxing',
#  'baike33/pokemon-add-wm', 'Haziqsayyed/expression-dataset', 'Vijaymax/User18',
#  'JeremyArancio/lotr-book', 'cakiki/stack-smol-xxl',
#  'alphaxtraboostnews/Alpha-Xtra-Boost',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/9c4666e9', 'Quinm101/ATpubmed',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/840ef337', 'hohai/aclImdb',
#  'diffusers/starbucks-example', 'diffusers/keramer-face-example',
#  'diffusers/pighead-example', 'diffusers/potato-head-example',
#  'diffusers/cat-toy-example', 'scofieldlin/scofieldlin_2',
#  'Mayank-02/indian_legal_text', 'Fredithefish/GPTeacher-for-RedPajama-Chat',
#  'pxovela/Vodka_v2_training_data', 'Cyb3rWard0g/ATTCKGroups',
#  'mazkobot/train_valid_digit_mask_augmented_raw', 'Thouph/incomplete_224',
#  'hoangho/dataset', 'gimmaru/ex_eval_results', 'vargha/liquidmarket_chatbot',
#  'under-tree/prepared-yagpt', 'AlphaXtraBoost/AlphaXtraBoost',
#  'September1549/test', 'Soyoung/HistRED', 'mjavadmt/mbti-persian-twitter',
#  'bjoernp/gaps_jpn', 'hlillemark/c4_t5_packed', 'hashirerf/mujiano',
#  'Norquinal/WizardLM_alpaca_claude_evol_instruct_70k',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-001-c512', 'ra4wv2/qa',
#  'EdisonBlack/checkpoint', 'jermani/qisui', 'ttss/query-based-summarization',
#  'mtyrrell/ikitracs_training_dataset_FINAL', 'ACCA225/sdconfig2',
#  'Neu256/Arc-dataset', 'Gabriel/synthetic_competing_risk',
#  'Fine/your-dataset-name', 'lukasmoeller/chat-combined-code',
#  'xeonkai/tagged_articles', 'aleh/aims_2', 'deepghs/anime_head_detection',
#  'babanghus/jakkhgty', 'sled-umich/MindCraft2', 'landersanmi/BilbaoCaptions2',
#  'Linaqruf/cagliostro-colab-ui', 'Dampish/DDDC', '9wimu9/sinhala_eli5',
#  'deepghs/anime_face_detection',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-it1-sg-001', 'hys564219/sd_configs',
#  'Sakizu/Figure', 'mask-distilled-one-sec-cv12/chunk_2',
#  'mask-distilled-one-sec-cv12/chunk_0', 'mask-distilled-one-sec-cv12/chunk_1',
#  'mask-distilled-one-sec-cv12/chunk_4',
#  'cj-mills/hagrid-classification-512p-no-gesture-150k-zip', 'ilyamooorg/test',
#  'mask-distilled-one-sec-cv12/chunk_9', 'bart2020/HR_Attrition',
#  'mask-distilled-one-sec-cv12/chunk_6', 'mask-distilled-one-sec-cv12/chunk_5',
#  'Fine/kafu', 'Abrumu/Fashion_controlnet_dataset_V3', 'aleh/aims_4',
#  'mask-distilled-one-sec-cv12/chunk_3', 'g4m3r/T1w_MRI_Brain_Slices',
#  'mask-distilled-one-sec-cv12/chunk_7', 'mask-distilled-one-sec-cv12/chunk_8',
#  'SimonasK/AudioCaps-Spectrograms', 'ProjectFisokuhle/insure_docs',
#  'yasinaryanfard/Khatnegardatasets', 'dhmeltzer/asks_validation_embedded',
#  'chaimudi/chuimudi', 'DanielaSaavedraL/saleswiz_is_positive',
#  'DanielaSaavedraL/saleswiz_is_relevant', 'factored/saleswiz_is_positive',
#  'EndMO/rte', 'Amiri/Google-Play-Reviews-for-Sentiment-Analysis',
#  'IdoAi/FypDatasetWithSplitsRgb', 'makhariana/ptg', 'Jacek6/M',
#  'pszemraj/dolly_hhrlhf-text2text', 'cgulse/alpaca-cleaned-tr',
#  'mask-distilled-one-sec-cv12/chunk_12', 'mask-distilled-one-sec-cv12/chunk_14',
#  'mask-distilled-one-sec-cv12/chunk_11', 'mask-distilled-one-sec-cv12/chunk_13',
#  'FidelOdok/DOA_dataset', 'mask-distilled-one-sec-cv12/chunk_15',
#  'plgfro/Kaggles-Galaxy-Zoo-Dataset', 'mask-distilled-one-sec-cv12/chunk_19',
#  'alpayariyak/IAM_Sentences', 'mask-distilled-one-sec-cv12/chunk_16',
#  'PocketDoc/RUCAIBox-Story-Generation-Alpaca', 'CVdatasets/food27',
#  'mask-distilled-one-sec-cv12/chunk_17', 'dcyoung/langchain-docs',
#  'AlekseyKorshuk/lmeh-hh', 'kunishou/cnn-dailymail-27k-ja',
#  'mask-distilled-one-sec-cv12/chunk_18', 'keeper-tax/income-w2-real',
#  'kunishou/hh-rlhf-49k-ja', 'TheMrguiller/BilbaoQA2', 'IsraelSonseca/UCFSPORTS',
#  'AlekseyKorshuk/lmeh-chai-davinci', 'edarchimbaud/earnings-sp500',
#  'benjaminway/produktivniordinace', 'yang19991129/kagglesd',
#  'AlekseyKorshuk/lmeh-chai-synthetic',
#  'AlekseyKorshuk/lmeh-chai-davinci-vs-lit', 'izumi-lab/piqa-ja-mbartm2m',
#  'ctoth/MOO_code', 'mask-distilled-one-sec-cv12/chunk_28',
#  'mask-distilled-one-sec-cv12/chunk_26', 'mask-distilled-one-sec-cv12/chunk_24',
#  'fastxchoda/fastxfullmovie', 'mask-distilled-one-sec-cv12/chunk_10',
#  'mask-distilled-one-sec-cv12/chunk_25', 'mask-distilled-one-sec-cv12/chunk_27',
#  'mask-distilled-one-sec-cv12/chunk_22', 'Aoppenhiem/pushshift-reddit',
#  'Ardi98/autotrain-data-ardi', 'mask-distilled-one-sec-cv12/chunk_20',
#  'mask-distilled-one-sec-cv12/chunk_21', 'serenas/posepics',
#  'dmayhem93/self-critiquing-base-selected-900-prompt-continuation',
#  'lucasmccabe-lmi/CodeAlpaca-20k', 'cdsi-nlp-workshops/synthetic_qa',
#  'thewall/alphaVbeta3', 'hlillemark/c4_t5_100',
#  'chenbowen-184/events-marketing-sample', 'izumi-lab/sciq-ja-mbartm2m',
#  'Duskfallcrew/HF_BACKUP-Colab', 'RIPL/TTIC-common', 'marasama/nva-aging',
#  'abhilashpotluri/lfqa_summary',
#  'Nan-Do/instructional_code-search-net-javacript',
#  'Nan-Do/instructional_code-search-net-java',
#  'Nan-Do/instructional_code-search-net-ruby', 'Juno360219/Ne',
#  'Nan-Do/instructional_code-search-net-go',
#  'Nan-Do/instructional_code-search-net-php', 'Jumtra/for_finetune_mpt7b_v2',
#  'lindaharumei/YklHui', 'joey234/mmlu-abstract_algebra', 'joey234/mmlu-anatomy',
#  'joey234/mmlu-astronomy', 'joey234/mmlu-business_ethics',
#  'joey234/mmlu-clinical_knowledge', 'joey234/mmlu-college_biology',
#  'joey234/mmlu-college_chemistry', 'joey234/mmlu-college_computer_science',
#  'joey234/mmlu-college_mathematics', 'joey234/mmlu-college_medicine',
#  'joey234/mmlu-college_physics', 'joey234/mmlu-computer_security',
#  'joey234/mmlu-conceptual_physics', 'joey234/mmlu-econometrics',
#  'joey234/mmlu-electrical_engineering', 'joey234/mmlu-elementary_mathematics',
#  'joey234/mmlu-formal_logic', 'joey234/mmlu-global_facts',
#  'joey234/mmlu-high_school_biology', 'joey234/mmlu-high_school_chemistry',
#  'joey234/mmlu-high_school_computer_science',
#  'joey234/mmlu-high_school_european_history',
#  'joey234/mmlu-high_school_geography',
#  'joey234/mmlu-high_school_government_and_politics',
#  'joey234/mmlu-high_school_macroeconomics',
#  'joey234/mmlu-high_school_mathematics',
#  'joey234/mmlu-high_school_microeconomics', 'joey234/mmlu-high_school_physics',
#  'joey234/mmlu-high_school_psychology', 'joey234/mmlu-high_school_statistics',
#  'joey234/mmlu-high_school_us_history',
#  'joey234/mmlu-high_school_world_history', 'joey234/mmlu-human_aging',
#  'joey234/mmlu-human_sexuality', 'joey234/mmlu-international_law',
#  'joey234/mmlu-jurisprudence', 'joey234/mmlu-logical_fallacies',
#  'joey234/mmlu-machine_learning', 'joey234/mmlu-management',
#  'joey234/mmlu-marketing', 'joey234/mmlu-medical_genetics',
#  'joey234/mmlu-miscellaneous', 'joey234/mmlu-moral_disputes',
#  'joey234/mmlu-moral_scenarios', 'joey234/mmlu-nutrition',
#  'joey234/mmlu-philosophy', 'joey234/mmlu-prehistory',
#  'joey234/mmlu-professional_accounting', 'joey234/mmlu-professional_law',
#  'joey234/mmlu-professional_medicine', 'joey234/mmlu-professional_psychology',
#  'joey234/mmlu-public_relations', 'joey234/mmlu-security_studies',
#  'joey234/mmlu-sociology', 'joey234/mmlu-us_foreign_policy',
#  'joey234/mmlu-virology', 'joey234/mmlu-world_religions',
#  'younyokel/PrincessPeachMovie', 'yongchoooon/fire_aihub_30',
#  'shrinath-suresh/so_5k_with_short_answer', 'dongyoungkim/AAE_TEST',
#  'averageandyyy/brainheck_asr_train', 'averageandyyy/brainheck_asr_test',
#  'yanchao/cifar10buqi', 'mask-distilled-one-sec-cv12/chunk_36',
#  'mask-distilled-one-sec-cv12/chunk_33', 'mask-distilled-one-sec-cv12/chunk_34',
#  'mask-distilled-one-sec-cv12/chunk_30', 'mask-distilled-one-sec-cv12/chunk_31',
#  'mask-distilled-one-sec-cv12/chunk_35', 'mask-distilled-one-sec-cv12/chunk_29',
#  'ShiwenNi/PatentQA-100', 'mask-distilled-one-sec-cv12/chunk_32',
#  'mask-distilled-one-sec-cv12/chunk_23', 'FelipeCODX/regularization',
#  'shrinath-suresh/so_forum_docs_blogs_all',
#  'mask-distilled-one-sec-cv12/chunk_37', 'pongping/your-dataset-name',
#  'andersonbcdefg/reward-modeling-long-tokenized', 'dongyoungkim/A_TRAIN',
#  'andersonbcdefg/reward-modeling-short-tokenized',
#  'alphaignitemaleenhancementusa/AlphaIgniteMaleEnhancement',
#  'sumbulathio/suluthijao', 'BNNT/IPQA', 'Jumtra/for_finetune_mpt7b_v3',
#  'RossVermouth/chensu_test_dataset', 'hudsongeorge/langchain-docs',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/978d0222',
#  'mask-distilled-one-sec-cv12/chunk_46', 'mask-distilled-one-sec-cv12/chunk_45',
#  'Dzeniks/BBC-article', 'mask-distilled-one-sec-cv12/chunk_44', 'jxu124/invig',
#  'RossVermouth/chensu_test_dataset1', 'RossVermouth/chensu_test_dataset2',
#  'mask-distilled-one-sec-cv12/chunk_47', 'devmaple/MLPhotoEditorView',
#  'mask-distilled-one-sec-cv12/chunk_43', 'hlillemark/c4_t5_pretrain',
#  'mesolitica/crawl-c-cari-com-my', 'fuflik/1', 'dw0815/butterfly',
#  'cr7Por/ffhq_controlnet_5_18_23', 'olllpp/99', 'next-social/reddit_crush',
#  'charmanQ/xq', 'wsapi/book', 'gutvitanews/Gut-Vita', 'dw0815/flowers123',
#  'Fredithefish/ShareGPT-Unfiltered-RedPajama-Chat-format',
#  'getcryptosoft/cryptosoft',
#  'Fredithefish/ShareGPT-unfiltered-alpaca-lora-format',
#  'getcryptosoft/cryptosofterfahrungen',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/71e9d947',
#  'mask-distilled-one-sec-cv12/chunk_52', 'mask-distilled-one-sec-cv12/chunk_48',
#  'mask-distilled-one-sec-cv12/chunk_42', 'mask-distilled-one-sec-cv12/chunk_49',
#  'mask-distilled-one-sec-cv12/chunk_39', 'mask-distilled-one-sec-cv12/chunk_41',
#  'mask-distilled-one-sec-cv12/chunk_38', 'mask-distilled-one-sec-cv12/chunk_51',
#  'TrainingDataPro/facial_keypoint_detection', 'seventeen/wangyi_data',
#  'mask-distilled-one-sec-cv12/chunk_40', 'TrainingDataPro/pose_estimation',
#  'vanaminddrops/VanaMind', 'remedyskintagscam/remedyskintagscam',
#  'mask-distilled-one-sec-cv12/chunk_50',
#  'linhtran92/deduplicated_dataset_100hrs_wer0_cut',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/0074e854',
#  'psyche/klue-wos-prompt-generation', 'CCRs/Ranobes-Datasets',
#  'AIML-TUDA/socio-moral-image-rationales',
#  'edarchimbaud/earnings-estimate-sp500',
#  'society-ethics/stable-bias-generations', 'GutVitaUS/GutVitaUS', 'Lasry/amine',
#  'reven404/hello-world', 'sajid73/test-dataset', 'GutVitaPills/GutVitaReviews',
#  'mask-distilled-one-sec-cv12/chunk_62', 'mask-distilled-one-sec-cv12/chunk_53',
#  'mask-distilled-one-sec-cv12/chunk_60', 'mask-distilled-one-sec-cv12/chunk_59',
#  'mask-distilled-one-sec-cv12/chunk_57', 'mask-distilled-one-sec-cv12/chunk_55',
#  'mask-distilled-one-sec-cv12/chunk_54', 'mask-distilled-one-sec-cv12/chunk_56',
#  'linhtran92/dataset_500hrs_wer0', 'mask-distilled-one-sec-cv12/chunk_58',
#  'TFLai/Turkish-Dialog-Dataset', 'mask-distilled-one-sec-cv12/chunk_61',
#  'sehunnnn/123', 'mphonkala/absolom_voice', 'edarchimbaud/eps-revisions-sp500',
#  'Pranavkpba2000/skin_cancer_complete_dataset_resized', 'DDDSSS/en-zh-dataset',
#  'ValhallaSpace/VDBase', 'stefanbschneider/dummy-dataset', 'asoria/duorc',
#  'edarchimbaud/eps-trend-sp500', 'mask-distilled-one-sec-cv12/chunk_70',
#  'mask-distilled-one-sec-cv12/chunk_69', 'mask-distilled-one-sec-cv12/chunk_64',
#  'edarchimbaud/revenue-estimate-sp500', 'mask-distilled-one-sec-cv12/chunk_66',
#  'mask-distilled-one-sec-cv12/chunk_68', 'mask-distilled-one-sec-cv12/chunk_67',
#  'J-Mourad/TokenizedMNAD.v2', 'petersa2/CodeNet',
#  'mask-distilled-one-sec-cv12/chunk_71',
#  'spacemanidol/Product-Search-Images-v0.1', 'asoria/glue-test', 'asoria/mnist',
#  'yehiase/ulikoa', 'AntonioRenatoMontefusco/kddChallenge2023',
#  'MaximOm/autotrain-data-aroma-therapy-consultant',
#  'AlekseyKorshuk/gpt-roleplay-realm-chatml', 'codergurl718/Know-It-All-Bot',
#  'mesolitica/crawl-hardwarezone-sg', 'linhtran92/final_dataset_500hrs_wer0',
#  'ReehaKhan/nlptraining', 'Ru3ll/zindi_test', 'abobster/swans', 'hilop/test_d',
#  'Pipatpong/data_code_merge', 'soteroshanthi/courses-dataset',
#  'palliyanaflower/Kahana_Beach_Park',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-301-c1024', 'Mikecyane/kinn',
#  'torchgeo/revisiting-rs-ssl-benchmarks', 'yanbax/CIFAKE_autotrain_compatible',
#  'Saiteja/movie-poster', 'Orr-z/Electronics',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-301-c1024-sbldt1',
#  'pnadel/npi_all_transcripts', 'mask-distilled-one-sec-cv12/chunk_63',
#  'pnadel/npi_transcripts_index', 'mask-distilled-one-sec-cv12/chunk_65',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-301-c1024-sbldt2',
#  'mask-distilled-one-sec-cv12/chunk_74', 'mask-distilled-one-sec-cv12/chunk_73',
#  'mask-distilled-one-sec-cv12/chunk_78', 'mask-distilled-one-sec-cv12/chunk_76',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-301-c1024-sbldt3',
#  'mask-distilled-one-sec-cv12/chunk_72',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-301-c1024-sbldt5',
#  'mask-distilled-one-sec-cv12/chunk_77', 'mask-distilled-one-sec-cv12/chunk_79',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-302-c1024',
#  'mask-distilled-one-sec-cv12/chunk_75',
#  'Marnus123/autotrain-data-groceries-database-l', 'phongmt184172/small_mtet',
#  'BlitzKriegM/dataset1',
#  'zh-tw-llm-dv/zh-tw-pythia-ta8000-v1-e1-tr_sg-201-c1024',
#  'datablations/python-megatron', 'alpayariyak/IAM_Sentences_LLaVA',
#  'Kyo-Kai/Fsg_pp_files', 'simonry14/luganda-news-articles',
#  'Cheetor1996/Kotone_Shirakawa', 'andyh28/testing', 'Mjarrin/ridge100',
#  'mask-distilled-one-sec-cv12/chunk_84', 'mask-distilled-one-sec-cv12/chunk_80',
#  'mask-distilled-one-sec-cv12/chunk_83', 'mask-distilled-one-sec-cv12/chunk_88',
#  'mask-distilled-one-sec-cv12/chunk_82', 'mask-distilled-one-sec-cv12/chunk_86',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/0c5dfa67',
#  'mask-distilled-one-sec-cv12/chunk_87', 'fouadbakour/eurisko-website',
#  'mask-distilled-one-sec-cv12/chunk_89', 'KyonBS/tachiaoi-kunoichiTsubaki',
#  'mask-distilled-one-sec-cv12/chunk_85', 'mask-distilled-one-sec-cv12/chunk_81',
#  'tourmalinecat/paintings', 'Dampish/shrgpt', 'sunjasa/dulkazastreaming',
#  'BIDJOE/chvg-yolo', 'Pin543/Pinkybaby', 'momo345/Captioning',
#  'KRJudge/TestKOJO', 'Dampish/sharegpt-alpaca-unfiltered-94k', 'Crodymi/Income',
#  'doushabao4766/weibo_ner_knowledge_V3_wc',
#  'linhtran92/viet_youtube_asr_corpus_v2', 'yeshpanovrustem/ner-kazakh',
#  'aiensured/textpipeline', 'Dampish/StellarX', 'Dampish/Stellar5-1200',
#  'nbalepur/web_nlg_template3', 'Dampish/Stellar-chat-full',
#  'psyche/causal-lm-dataset', 'chao1224/ChatDrug_prompt',
#  'cognizedeepak/CognizeDeepak', 'Nan-Do/instructional_code-search-net-python',
#  'chao1224/ChatDrug_data', 'Alextab163/Josef163',
#  'hlillemark/flores200_devtest_mt5-1b-flores200-baseline',
#  'shthom2004/sousousousou', 'Travad98/sogc-trademarks-1883-2001',
#  'coeuslearning/customerqueries', 'Ruqoyya/movie-poster-generation',
#  'SageBio/testdataset', 'Kartick/textualinversion',
#  'Travad98/donut-docparsing-sogc-trademarks-1883-2001',
#  'mask-distilled-one-sec-cv12/chunk_97', 'FidelOdok/DOA_datasetSmall',
#  'OpenShape/openshape-objaverse-embeddings',
#  'mask-distilled-one-sec-cv12/chunk_91', 'mask-distilled-one-sec-cv12/chunk_96',
#  'mask-distilled-one-sec-cv12/chunk_98', 'mask-distilled-one-sec-cv12/chunk_93',
#  'mask-distilled-one-sec-cv12/chunk_92', 'mask-distilled-one-sec-cv12/chunk_94',
#  'Thouph/tag_part', 'aizenpowerreport/Aizen-Power',
#  'mask-distilled-one-sec-cv12/chunk_90', 'alpayariyak/IAM_Sentences_LLaVA_json',
#  'mask-distilled-one-sec-cv12/chunk_95', 'naxalpha/islamic-audios',
#  'mask-distilled-one-sec-cv12/chunk_99', 'RobbeD/csgo-metadata',
#  'wyp/cblue-cmeee', 'basesssssp/bad-kemono-negative-embedding',
#  'dikzas/seterimonlinejuk', 'katielink/synapse_test_dataset',
#  '0x22almostEvil/semantics-ws-qna-oa', 'mask-distilled-one-sec-cv12/chunk_106',
#  'averageandyyy/imda_dataset', 'svencard/sd',
#  'mask-distilled-one-sec-cv12/chunk_107',
#  'mask-distilled-one-sec-cv12/chunk_105', 'jiyujie/enndme',
#  'mask-distilled-one-sec-cv12/chunk_109',
#  'mask-distilled-one-sec-cv12/chunk_101',
#  'mask-distilled-one-sec-cv12/chunk_100', 'RobbeD/csgo-skins-dataset',
#  'mask-distilled-one-sec-cv12/chunk_103',
#  'mask-distilled-one-sec-cv12/chunk_108', 'MojtabaDelavar97/quran_36-55',
#  'baizhi002/myselftran', 'mask-distilled-one-sec-cv12/chunk_102',
#  'AizenPowerUSA/AizenPowerUSA', 'mask-distilled-one-sec-cv12/chunk_104',
#  'Logic123456789/luotuoQA-B', 'e-mohammadi/x',
#  'mask-distilled-one-sec-cv12/chunk_111', 'ttss/one-sentence-summarization',
#  'mask-distilled-one-sec-cv12/chunk_112', 'orlinaqw/bng',
#  'Shoubhik8/instruct_data', 'mask-distilled-one-sec-cv12/chunk_110',
#  'tak15/nva-deathface', 'mask-distilled-one-sec-cv12/chunk_114',
#  'mask-distilled-one-sec-cv12/chunk_113',
#  'mask-distilled-one-sec-cv12/chunk_116', 'husangui/lora',
#  'lucadiliello/squad_as2', 'mask-distilled-one-sec-cv12/chunk_117',
#  'fnlp/moss-003-sft-data', 'Shoubhik8/instruct_data_train',
#  'Shoubhik8/instruct_data_valid', 'aizenpowerblogger/Aizen-Power',
#  'LoliOverflow/DUMP', 'KELONMYOSA/dusha_emotion_audio', 'stilletto/earth_canny',
#  'ethanwan/trash_classification', 'Frankiezzz/civitai_depo',
#  'ztphs980/taptap_datasets', 'mask-distilled-one-sec-cv12/chunk_126',
#  'mask-distilled-one-sec-cv12/chunk_125',
#  'mask-distilled-one-sec-cv12/chunk_118',
#  'mask-distilled-one-sec-cv12/chunk_115', 'squarelike/ReverseProxy-OAI-Log',
#  'mask-distilled-one-sec-cv12/chunk_120',
#  'mask-distilled-one-sec-cv12/chunk_122',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/6a171c66', 'AlketaR/testing',
#  'mask-distilled-one-sec-cv12/chunk_123', 'AlketaR/embedded_faqs_medicarealk',
#  'mask-distilled-one-sec-cv12/chunk_119', 'voidful/StrategyQA',
#  'mask-distilled-one-sec-cv12/chunk_124', 'voidful/CommaQA',
#  'ZurichNLP/rsd-ists-2016', 'voidful/fermi', 'voidful/GSM-IC', 'voidful/qrecc',
#  'voidful/MuSiQue', 'dassum/celebrity-identities', 'voidful/2WikiMultihopQA',
#  'voidful/csqa2', 'mask-distilled-one-sec-cv12/chunk_131', 'voidful/IIRC',
#  'mask-distilled-one-sec-cv12/chunk_127',
#  'mask-distilled-one-sec-cv12/chunk_128', 'voidful/EduQG', 'voidful/ReClor',
#  'mask-distilled-one-sec-cv12/chunk_129', 'arbml/CalliFontMedium',
#  'EqUaL90/nga_modis_sr_qc250m1', 'Q-b1t/Dogs_Emotions_Dataset',
#  'mask-distilled-one-sec-cv12/chunk_130', 'skczwaluho/erumosmac',
#  'mask-distilled-one-sec-cv12/chunk_132',
#  'mask-distilled-one-sec-cv12/chunk_133', 'shawarmas/listofbannedwordsin',
#  'winglian/instruct-en-cleaned', 'jxu124/cc_sbu_align',
#  'skeskinen/TinyStories-GPT4', 'skeskinen/TinyStories-GPT3.5',
#  'jxu124/refcocoplus', 'khalidalt/books_ocr', 'olmer/wiki_paragraphs',
#  'olmer/wiki_mpnet_embeddings', 'ucalyptus/shrutilipi_bengali',
#  'jxu124/objects365', 'yetesh/ukj', 'cladius/temp',
#  'mask-distilled-one-sec-cv12/chunk_139', 'anwarshome/RT_temp',
#  'mask-distilled-one-sec-cv12/chunk_135',
#  'mask-distilled-one-sec-cv12/chunk_137',
#  'mask-distilled-one-sec-cv12/chunk_136', 'FMunyoz/AMB',
#  'mask-distilled-one-sec-cv12/chunk_134', 'Leventk/Veri_kuma',
#  'Jakarinamina/Rapidos-y-fuirosos-10', 'Jakarinamina/KomatKamit.VER',
#  'mask-distilled-one-sec-cv12/chunk_121', 'Jakarinamina/Pelisplus.Mex',
#  'Jakarinamina/Flixmediatube', 'Jakarinamina/Boyokelara', 'kaso920/nva-ririk',
#  'FidelOdok/DOA_datasetmini', 'ma2za/many_emotions',
#  'ashiyakatuka11/empathetic_dialogues_context', 'younyokel/JessicaHuang',
#  'cjensen/crowdsourced-poor-images', 'mask-distilled-one-sec-cv12/chunk_148',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/05e388fb',
#  'mask-distilled-one-sec-cv12/chunk_141',
#  'mask-distilled-one-sec-cv12/chunk_146',
#  'mask-distilled-one-sec-cv12/chunk_145',
#  'mask-distilled-one-sec-cv12/chunk_147',
#  'mask-distilled-one-sec-cv12/chunk_143',
#  'mask-distilled-one-sec-cv12/chunk_142',
#  'mask-distilled-one-sec-cv12/chunk_138',
#  'mask-distilled-one-sec-cv12/chunk_144',
# ...
#  'Dixone438/Dixone438', 'hzrr/audio7z', 'EclipsePhage/langchain-docs-csv',
#  'spacebytemeorg/mydataset', 'chiukit/test-kit', 'apslosu/jiupokujy',
#  'visheratin/laion-coco-nllb', 'alicewrld/dontouch', 'NonCute/bsd',
#  'rgthyyuipou/dyjuyiopouy', 'retrytuyiuopi/yuikupukyty', 'yuiuopou/ytuiopojhh',
#  'thyujilpoiu/yukioyfeee', 'yjukiuopou/vdsgrthrgwwaa', 'Sam007p/demo',
#  'aanencok/romovies', 'fidil/alya', 'aanencok/hfydtrete5rfe5rew',
#  'kendangkoplo/hghfyyrtyrt', 'fidil/rytgey', 'Adi-0-0-Gupta/Hands-Dataset-Test',
#  'anjay1987/flimePT', 'makabakalale/4444', 'Nadav/pixel_glue_mnli_noisy_ocr',
#  'anjay1987/slowfilm', 'anjay1987/completdublado', 'anjay1987/polpo',
#  'Younst/Zoju', 'ConsciousEnergies/LENR', 'moviess87/babadell', 'Alexxya/YunA',
#  'Diadon/LENR_Dataset', 'suuww/ptbr', 'yoUnsTT/FilMe', 'suuww/itcompleto',
#  'svenjars/dataset_new', 'silikis987/anjay', 'ahpha/chtholly',
#  'silkis1876/lily21', 'makabakalale/ceshi1', 'Jaiver123/axenai-test',
#  'supinyu/goat-chinese', 'gaganc/harveyray', 'gaganc/gaganchattha1',
#  'Jaiver123/axen-test', 'Jaiver123/axenai-1', 'yayah/sewee',
#  'Jaiver123/axenart', 'liraninau/liraninau', 'liraninau/Dererdrese',
#  'axenai/axenai-1', 'liraninau/Dererdres', 'axenai/axenaitest',
#  't1k/khajiitspeak', 'erttyyuuipuoy/ikulpytae', 'maximousblk/grading',
#  'nhjhkiluopou/bbyjuyikulopi', 'Dererdrese/skf204', 'ujykio/hguiopiuya',
#  'gagan3012/areta_v5', 'Lafyette3652/Lafyette3652',
#  'NYUSHPRP/ModelCofferRoster', 'necranom/harveyray', 'nadare/rvc-v3j',
#  'marchue/kaleb', 'jordmac/rojas', 'cookxe/mae', 'summerholic/courtney',
#  'Chatman4541/Chatman4541', 'jmoffatt123/guerra', 'Shemika8593/Shemika8593',
#  'ruslan19986/josef', 'konnechkas/pittman', 'jmay425/ioan', 'arvindsw/morrow',
#  'serezhaiugov/emili', 'shadrina/hunter', 'alicewrld/cute', 'dukati2263/aryan',
#  'crozwe/branch', 'tiri1231/nva-kiru', 'scac/kamal', 'minhew/sutton',
#  'Jetson93/analyze', 'mprzymus/text2tile', 'veritye/luna',
#  'Nadav/pixel_glue_qqp_noisy_ocr', 'alicewrld/emoahh', 'sab593/luna',
#  'hijn/shane', 'sivan22/fischel', 'lovkachvlegende/coleman',
#  'skobelinvitaliy/bell', 'dmiegovcev/malik', 'a125149/meredit',
#  'AddictiveFuture/embeddings', 'albinapoti/hshelton', 'subhaan/zamora',
#  'tangorock/orr', 'jeffaafedt/hari', 'sbunkoff/chad', 'vmanj/vmanj',
#  'saa777/mitchell', 'LightGCN/embeddings', 'ariefdidu/filmecompletos',
#  'MTINET/time',
#  'chrisswebberproplayersonlycbdgummies/chrisswebberproplayersonlycbdgummies',
#  'spneshaei/imdb_after_522', 'ninjawick/sholay1',
#  'dmayhem93/agieval-gaokao-biology', 'dmayhem93/agieval-gaokao-chemistry',
#  'dmayhem93/agieval-gaokao-chinese', 'dmayhem93/agieval-gaokao-english',
#  'dmayhem93/agieval-gaokao-geography', 'dmayhem93/agieval-gaokao-history',
#  'dmayhem93/agieval-gaokao-mathqa', 'dmayhem93/agieval-gaokao-physics',
#  'dmayhem93/agieval-logiqa-en', 'dmayhem93/agieval-logiqa-zh',
#  'dmayhem93/agieval-lsat-ar', 'dmayhem93/agieval-lsat-lr',
#  'dmayhem93/agieval-lsat-rc', 'dmayhem93/agieval-sat-en',
#  'dmayhem93/agieval-sat-en-without-passage', 'dmayhem93/agieval-sat-math',
#  'RANSPB/embedded_faqs_medicare', 'Waster3012/fever_augemented',
#  'utiqoril/yhujif', 'Abdelkareem/wikihow-arabic-summarization',
#  'Abdelkareem/simple-benchmark-arabic-summarization',
#  'Abdelkareem/arabic-article-summarization', 'Abdelkareem/arabic-bbc-news',
#  'Abdelkareem/Arabic-article-summarization-30-000',
#  'marianna13/layout-molecules', 'ninjawick/bf2042', 'shibing624/sts-sohu2021',
#  'pykeio/vtuber-chats-en',
#  'LukeCombsWeightLossGumBuy/LukeCombsWeightLossGummies',
#  'LukeCombsWeightLossGumBuy/LukeCombsWeightLossGummiesUS',
#  'LukeCombsWeightLossGumBuy/MiracleRootGummiesLukeCombs',
#  'LennardZuendorf/legalis', 'fugueweb/foc-webscrape',
#  'SSSSSSSSSSSJJJJJJJJJJJJJ/Hello', 'msislam/marc-multilingual-encodings-v4',
#  'madebyollin/soa-full', '0xharib/xword3', 'rhalim01/test3',
#  'Alexey5676/emb_test', 'msislam/marc-code-mixed-small', 'tasksource/BioNLI',
#  'Rami/prompts_eval', 'karmiq/glove', 'gagan3012/areta_v6',
#  'xin1997/bugfix_pretraining', 'CoreGroup/reset',
#  'ChristophSchuhmann/basic-math-problems-with-step-by-step-solutions',
#  'drumwell/generadai-sample', 'YeungNLP/ultrachat', 'Kevin99z/redial_unicrs',
#  'ggarcia209/PV03', 'coding-Jay/Synthetic-Datasets-Unity-CV',
#  'Kevin99z/inspired_unicrs', 'smaciu/bee-wings-large',
#  'dgslibisey/MuSiQue_subset', 'sippycoder/RedPajama-Data-1T-no-cc-c4',
#  'vbfnst/repelistv', 'henrydz/first_sample_data',
#  'jondurbin/airoboros-gpt4-1.3', 'kuluchipoomani/kuluchupoomaniasas',
#  'madebyollin/soa-aesthetic', 'kuluchipoomani/samiopoiyyyt', 'dnjdsxor21/nkiwi',
#  'kuluchipoomani/panipoo', 'kuluchipoomani/tanjiro', 'torostrm/verpelis',
#  'kiluade/waifuCatVT', 'andersonbcdefg/guanaco-ai-filtered', 'Erniedenie/Test',
#  'upinpiak/ross', 'turkmen/ahmetkayavocals',
#  'ethansimrm/wmt_16_19_22_biomed_train_processed', 'upin224/PELISPLUS',
#  'conceptofmind/flan-open-llama-2k-eos-only', 'marcospiau/colbert-pt-data',
#  'ickma/sec_AA', 'seyyedaliayati/solidity-dataset-test',
#  'xzuyn/Stable-Diffusion-Prompts-Deduped-2.008M', 'ethansimrm/patTR_biomed_raw',
#  'curezapo/jeeb', 'pvduy/lima_vicuna_format',
#  'hivaze/emphatical_daily_dialogues', 'hysts-samples/sample-user-preferences',
#  'ickma/sec_shots', 'Martscribe/cagliostro-colab-ui', 'Raffles/ru_data',
#  'Zealoves/zealovesnora', 'cindyceye/cindyyun', 'LaraTessa552/LaraTessa',
#  'larasa/cagliostro-colab-ui', 'sintayo/sinchan', 'kazamanoa/noakazama',
#  'Qayvara/qayvaradiyo', 'cecelia1/cecelia1', 'Frazier454/Frazier454',
#  'fefe6/kelay7', 'Pavlina3562/Pavlina3562', 'Daniela3421/Daniela3421',
#  'Joynisha354/Joynisha354', 'Stephens4t55/Stephens4t55',
#  'Emilynn5776/Emilynn5776', 'Collier9034/Collier9034', 'Deliana493/Deliana493',
#  'Carter454322/Carter454322', 'Cassandrea888/Cassandrea888',
#  'Whitfield02933/Whitfield02933', 'MichaelaRyleigh15/MichaelaRyleigh',
#  'Sytira4432/Sytira4432', 'ronald44/ronaldhartono', 'Rodgers82393/Rodgers82393',
#  'Joslin8883/Joslin8883', 'Oliver53463/Oliver53463',
#  'Jalessica8839/Jalessica8839', 'Clayton82373/Clayton82373',
#  'Lakesia8855/Lakesia8855', 'yulianto8/bahar9', 'Solaria/solariayohan',
#  'AngelVirnica123/AngelVirnica', 'beatrice22/beatriceprincess', 'exezi/oeaice',
#  'exezi/ertyace', 'exezi/paoelce', 'ekaqab/veacue', 'ekaqab/kelaoe',
#  'ekaqab/renace', 'sheila002/black', 'ayna7/sherinay7', 'anwauf/ebaucer',
#  'anwauf/lekace', 'anwauf/refabce', 'rgtyhtuyiuo/gthyuyiuouiuu',
#  'gdytwer/dthyoipuiya', 'rgtrytiu/trhtujyilopiuusa',
#  'vfvdgfghjiuou/dsrgtytfvertyuio', 'kazamanoa/noakazama00',
#  'ai-habitat/OVMM_dataset', 'usimau/veauciae', 'usimau/fagce', 'usimau/neman',
#  'Victoriaa2/victoriazee', 'ai-habitat/OVMM_objects', 'iyucaf/vebayce',
#  'iyucaf/jamec', 'iyucaf/teara', 'alexan1/xander3', 'Graciaind/graciaindri',
#  'bobbie66/bobiehall', 'RubiMakena22/RubiMakena', 'xzcdsvsere/xswerebghuiopoi',
#  'dian9/aditomo9', 'dsftytuyuiou/fretrtyuyoipoiu', 'rgtrytuyioiu/rtyukio',
#  'czdsfrytuyiy/fertrytuyuiopu', 'yunitasari/yunitasariyun',
#  'ramon33/ramonsimpson', 'MaliyahSydney94/MaliyahSydney', 'Hellena/hellenanuna',
#  'ardiana4/putri8', 'KaydenCorinne41/KaydenCorinne', 'ayainaeris/ayainaeris',
#  'Fakhilla/fakhillaanuna', 'Judith22/judith', 'tyuyiuopu/tgytuyjkioipu',
#  'cxvcvfretrioi/retrytyuiop', 'gthytuyioui/hjikuopoukuy',
#  'rthytujyiuio/xvdgthytu', 'kellen7/sadavir1', 'Rossianna/rossiannaanuna',
#  'ReneeClarissa23/ReneeClarissa', 'parkpatricia/parkpatricia',
#  'BillGPT/OpenAI_embeddings_for_Wikipedia_Simple_English',
#  'alisson346/alissonjulianne', 'KeiraCameron23/KeiraCameron',
#  'paulette2/paulla', 'Claressta/claresstayoa', 'petersky/skypeter',
#  'kellen7/keilennas3', 'satwik9903/Meeting_transcripts', 'trgyiyt/wergtryujyu',
#  'awerertyyuy/rtryuiiytd', 'cfrgtryio/rttyyuiuuy', 'gthtyuoiy/ffytuioa',
#  'Marilyn400/marilyn', 'AliaMarlene46/AliaMarlene', 'carlymiya12/carlymiya',
#  'Thiarra/thiarrahaw', 'adinda1/zany6', 'jakeshim/jakeshim',
#  'NaNames/VitsPerTrainModel', 'jefri9/niko9', 'Courtney77/courtney', 'riuno/AF',
#  'BelindaDia46/BelindaDia', 'irene2/sungkar5', 'Violettan/violettania',
#  'donisalman/donisalman', 'adalyn321/adalynjohanna', 'Hayoon123/Idc',
#  'nakcnx/thai_subtitle', 'Cecilia770/cecilia', 'Syaqilla/syaqillaayu',
#  'YulianaKirsten72/YulianaKirsten', 'Melody003/melody', 'sujiwotejo/sujiwotejo',
#  'sylvia23/sylviaeliana', 'Kinanra/kinanrayuna',
#  'TeresaCasandra73/TeresaCasandra', 'dhyujikulopas/yjuykiupuou',
#  'dfertryt/thyjuykiupka', 'vdgtytuuioupu/yhtujykiopojty',
#  'cindyunitasari/cindyunitasari', 'Dean432/dean', 'Vanessa2/vanessangel',
#  'MarelyBriana52/MarelyBriana', 'hayden321/haydenmegan',
#  'fairyeshter/fairyeshter56', 'binhnx8/me_lo_dy_4', 'gustavo66/gustavo',
#  'Angelitta/angelittahayu', 'KinleyCharli/KinleyCharli', 'Arainne/arrainnesu',
#  'erikputrapetir/erikputrapetir', 'amyjaylee435/amyjaylee',
#  'AnnikaDiya72/AnnikaDiya', 'rivalangga/rivalangga', 'Hannalee/hannaleba',
#  'lauryn45/laurynrayna', 'Dennica/dennicaa', 'KyonBS/Desumi',
#  'dev7halo/bluehouse-national-petition', 'janevalery568/janevalery',
#  'dev7halo/korean-mcfaq', 'jazmyn/jazmynzoey', 'amanda45/amandajaqueline',
#  'alena586/alenapatricia', 'Kevet/Colab', 'smalleyes/Bot-memory',
#  'glorias568/gloriashelby', 'limcon/scarystructures',
#  'xzuyn/Stable-Diffusion-Prompts-Deduped-Alpaca-2.008M',
#  'KyonBS/desumiSubfolders', 'Cainiao-AI/LaDe-D', 'Cainiao-AI/LaDe-P',
#  'grace5789/gracejakayla', 'gillian789/gilliancassie',
#  'VASVASVAS/lora_not_mine', 'tamia678/tamiapiper', 'arthoho66/medicine',
#  'nakcnx/mcot_politics_news', 'BramVanroy/dolly-15k-dutch',
#  'tu67j/Superior-CBD-Gummies-Canada-price',
#  'tu67j/Superior-CBD-Gummies-Canada-Scam', 'kiluade/volley-waifu',
#  'tu67j/Superior-CBD-Gummies-Canada-Benefits', 'rizquuula/QASiNa',
#  'tu67j/Superior-CBD-Gummies-Canada-Reviews',
#  'tu67j/Superior-CBD-Gummies-Canada-Ingredients', 'D3v/temp',
#  'caball21/baseball', 'tu67j/Superior-CBD-Gummies-Canada-Overview',
#  'tu67j/Superior-CBD-Gummies-Canada-Buy',
#  'tu67j/Superior-CBD-Gummies-Canada-Cost',
#  'tu67j/Superior-CBD-Gummies-Canada-Work',
#  'tu67j/Superior-CBD-Gummies-Canada-Where', 'Vijaymax/User4', 'Vijaymax/Users',
#  'tu67j/Superior-CBD-Gummies-Canada-THE-MOST-POPULAR-CBD-GUMMY-BEARS-IN',
#  'asavanovich/sft_dataset',
#  'tu67j/Superior-CBD-Gummies-Canada-Shocking-scam-alert-must-read-before-buying',
#  'openpecha/STT_NS', 'Adi-0-0-Gupta/Hands-Dataset-Refined',
#  'tu67j/Superior-CBD-Gummies-Canada-Shocking-Report-Reveals-Must-Read-Before',
#  'tu67j/Superior-CBD-Gummies-Canada-Episode-Alert-Price-for-Sale-Website',
#  'tu67j/Superior-CBD-Gummies-Canada-Effective-Product-Cheap-Price',
#  'tu67j/Superior-CBD-Gummies-Canada-Shocking-Reviews-Cost-Revealed-Must-Check',
#  'tu67j/Superior-CBD-Gummies-Canada-REVIEWS-ULY-CBD-GUMMIES-REALLY',
#  'tu67j/Superior-CBD-Gummies-Canada-SHOCKING-Report-Know-The-Side-Effects',
#  'tu67j/Superior-CBD-Gummies-Canada-BALANCE-TRUSTED-OR-FRAUD-PRICE',
#  'miaomiaoha/zz', 'kim1111/car', 'DaniFrame/COLAPerturbed',
#  'ticoAg/HuatuoGPT_sft_data_v1', 'DaniFrame/HSOLPerturbed',
#  'woojinheo/codeparrot-train', 'woojinheo/codeparrot-valid',
#  'DaniFrame/MNLIPerturbed', 'DaniFrame/SST2Perturbed',
#  'MITCriticalData/unlabeled-5-top-cities-16-bit-depth',
#  'DaniFrame/PAWSPerturbed', 'Alegzandra/REDv2_EN_2',
#  'ilaria-oneofftech/con_uncond', 'ilaria-oneofftech/cond_uncond',
#  'SEVUNX/your-dataset-name', 'datacluster/colors-forest2',
#  'bitcoinrevolution/bitcoin-revolution-richard-branson', 'sweysfs/sweysfs',
#  'dazpyeorg/test1', 'dante7311/dante7311',
#  'bitcoinrevolution/bitcoin-revolution-gordon-ramsay', 'jeus04/jeus04',
#  'bitcoinrevolution/bitcoin-revolution-reviews', 'yukarcom/yukarcom',
#  'yonghyeon/neruo', 'brian42172/brennan', 'marmolpen3/sla-obligations-rights',
#  'bloodflowformula/JuvenonBloodFlow7', 'njukilpoui/kiuopota', 'yuiopo/ukuiopa',
#  'asfrtyuyoi/tyhuyjipas', 'bjguiuop/fdbggfdzse', 'thyujyoiu/fgbfhgoipioua',
#  'neve1849/amine', 'reesewe/reese', 'jortbogaerts/amaan', 'momod/john',
#  'snapey/nelson', 'warriorupgrademaleenhance/warriorupgrademaleenhance',
#  'maxbat/nelson', 'takatae/harrim', 'netto6900/cintosh', 'lar7474/tes',
#  'Rebeckah/bilder2', 'platonev/evydiwe', 'mrquake/jakubya', 'fashun/12',
#  'WStark/embedded_faqs_medicare', 'BloodFlow-7/juvenon-bloodflow-7',
#  'spneshaei/non_unicode_sst2', 'Shubham09/qnapolicy', 'yonghyeon/imsang',
#  'zudymuwojyvyk/ferguson', 'yonghyeon/pharm', 'yonghyeon/biochem',
#  'collabora/whisperspeech', 'chdcg/H3-OPT_template_dataset',
#  'TalTechNLP/AMIsum', 'Sunbird/Experimental-Speech-Salt-Runyankole-16k',
#  'Sasie/blogs-docs-splitted', 'LeLaboDuGame/NastorWhisperDS',
#  'juvenonnitricoxide/Juvenon-Nitric-Oxide-Blood-Flow-7',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/52a401f3',
#  'JuvenonBloodFlow7/JuvenonBloodFlow7', 'fashun/vo',
#  'TanveerAman/AMI-Processed', 'rarisenpai/apikeys',
#  'cemachelen/Leeds_SciML_SeaIce_2023', 'Lazyhope/RepoSnipy_eval',
#  'anatomyoncbdgummies/anatomyonecbdgummies', 'llm-book/jsnli',
#  'ProjectNekoFi/realistic', 'Rebeckah/bilder3', 'chiragtubakad/flan-final',
#  'Kugos/models_sd', 'atom-in-the-universe/audstock-10k', 'Yahaira/beans',
#  'zz990906/bird', 'Adi-0-0-Gupta/Action-Recognition', 'ickma/sec_GG',
#  'isepibo/isepibot', 'JayalekshmiGopakumar/falcon_doclaynet_v1',
#  'SkylaMonroe/Monroe', 'MiaObrien/Obrien', 'EloiseKlein/Klein',
#  'RosalieContreras/Contreras', 'AsmaStewart/Stewart', 'AnnRogers/Rogers',
#  'ZoyaFranco/Franco', 'InaayaJordan/Jordan',
#  'atom-in-the-universe/audstock-10k-music', 'TammyGibbons/Gibbons',
#  'ElizaMueller/Mueller', 'LeannePowers/Powers', 'niv-al/shp-sq',
#  'VioletChristensen/Christensen', 'DoraKerr/Kerr', 'OIOAZ/capitale',
#  'AlannaMooney/Mooney', 'KimCY/clothing_gen', 'KimCY/fjord-images',
#  'DemiLeighRichardson/Richardson', 'SamsungSAILMontreal/deepnets1m',
#  'Megaload/52314dsga', 'Vernei/cargos10000', 'private-demos/scat_argilla',
#  'ghezalahmad/concrete', 'zahoor54321/Urdu-ASR-flags', 'minimalt/MATH_amps',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/c5e1ddfc',
#  'results-sd-v1-5-sd-v2-1-if-v1-0-karlo/44583635',
#  'xortosrtm/altadefinizione-hds', 'd0rj/toxic_dvach_detoxified',
#  'HuggingFaceH4/open-llm-leaderboard-evaluations-results',
#  'HuggingFaceH4/open-llm-leaderboard-evaluations-requests',
#  'open-llm-leaderboard/evaluation-requests',
#  'open-llm-leaderboard/evaluation-results', 'Hotratx/reddit-topics-targz',
#  'ramandeepsaha/hcp', 'sdasdadas/juni3', 'marasama/nva-birth',
#  'marianna13/biorxiv_xml', 'achang/d4e_seq2class', 'marianna13/teams_qa',
#  'warmostrm/all-cb01-dec', 'QWFOJP/TEST', 'Yahaira/anemia-eyes',
#  'Davidf793/Docutest', 'lhoestq/remote-duckdb', 'adty-strmng01/ita-senzalimiti',
#  'sert121/SpiderSQL', 'praneeth6116/accent-change', 'ltkw98/fold1_tokenize',
#  'd0rj/rudetoxifier_data', 'fullbodyhealthcbdusa/FullBodyHealthCBDGummies',
#  'xr-xoxostrm/aldefinizione01', 'gmonsoon/falcon-retrain',
#  'Waster3012/fever_lines', 'zz990906/FL-invasive-birds', 'saragag/FlBirds',
#  'Samrita/FL-Invasive-Birds', 'rogernancada/florida_invaisive',
#  'NDSrex/Invasive-Birds-in-Florida', 'irodkin/ffhq_with_llava_shorter_captions',
#  'Weni/LLM-base-clean', 'abezguzov/nfe', 'Veryfull21/kyute',
#  'Neu256/arc-diffusion-dataset-1.1', 'usagichans/all', 'frosty11/Apologetics',
#  'gjballvn/art-bodies', 'cnut1648/fingerprint-outputs',
#  'sadmoseby/oassist_transformed', 'AlekseyKorshuk/updated-responses-preview',
#  'ethansimrm/PatTR_biomed_processed',
#  'ChristophSchuhmann/gutenberg-wiki-arxiv-pubmed-soda-summaries-top50percent',
#  'ChristophSchuhmann/gutenberg-wiki-arxiv-pubmed-soda-summaries-top65percent',
#  'Yinxuan/OCTScenes', 'private-demos/scat_argilla_target',
#  'Multimodal-Fatima/vocab_with_openai_classes', 'Madronus/bbox_test',
#  'thesis123/test_base_whisper', 'Confirm-Labs/pile_trigrams',
#  'pppppppppp2/xplaneperturbed', 'Jeoor/russian_dataset',
#  'Confirm-Labs/pile_bigrams', 'RecursosRegenerativos/piscinas_comuns',
#  'Sungeun/datasets-github-issues',
#  'trk-demo/dcd3ee64f0c1aba2eb9e0c0c16041c6cae40d780',
#  'ArtifactAI/arxiv-beir-500k-generated-queries',
#  'mirav/artistic-imagery-altcaptions',
#  'ArtifactAI/arxiv-beir-100k-generated-queries',
#  'ArtifactAI/arxiv-instruct-small', 'syp1229/Y_normal', 'andrewm9/andrewm9',
#  'idoav/baice', 'idoav/pacleo', 'idoav/eracue', 'lessspam/lessspam',
#  'wmcoops/wmcoops']

# %%
#dataset attributes
squad = list_datasets(with_details=True)[datasets.index('squad')]
#calling the python dataclass
pprint(squad.__dict__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c6228914f575> in <cell line: 2>()
#       1 #dataset attributes
# ----> 2 squad = list_datasets(with_details=True)[datasets.index('squad')]
#       3 #calling the python dataclass
#       4 pprint(squad.__dict__)
#
# TypeError: 'generator' object is not subscriptable

# %% [markdown]
# ### Generate Image Embeddings Using CNNs

# %% [markdown]
# We can better understand the CNNs by looking at some examples. In this section, we will use PyTorch to build from scratch a convolutional neural network that generates image embeddings.

# %% [markdown]
# #### Data Initialization

# %% [markdown]
# Before starting, below are some libraries we would need to build the convolutional network.

# %%
# Load in relevant libraries, and alias where appropriate
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# Given we will be working with a reasonable amount of data, we might want to process it on GPU rather than CPU. To do that, we need to transfer the data from CPU to GPU using ```torch.device```.

# %%
# Device will determine whether to run the training on GPU or CPU.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# The first step in building our network is downloading and initializing the dataset.
#
# The dataset we are downloading is *CIFAR-10* from HuggingFace.
#
# We will first download the training dataset by setting ```split = 'train'```, and the testing dataset after by setting ''split = 'test'```. While the training dataset includes 50,000 images divided into 10 classes, the test dataset includes 10,000 images divided into 10 classes.

# %%
# import CIFAR-10 dataset from HuggingFace
from datasets import load_dataset

dataset_train = load_dataset(
    'cifar10',
    split='train', # training dataset
    ignore_verifications=True  # set to True if seeing splits Error
)

dataset_train
# Out:
# Downloading builder script:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/799 [00:00<?, ?B/s]
# Downloading and preparing dataset cifar10/plain_text (download: 162.60 MiB, generated: 130.30 MiB, post-processed: Unknown size, total: 292.90 MiB) to /Users/jamesbriggs/.cache/huggingface/datasets/cifar10/plain_text/1.0.0/447d6ec4733dddd1ce3bb577c7166b986eaa4c538dcd9e805ba61f35674a9de4...
# Downloading data:   0%|          | 0.00/170M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /Users/jamesbriggs/.cache/huggingface/datasets/cifar10/plain_text/1.0.0/447d6ec4733dddd1ce3bb577c7166b986eaa4c538dcd9e805ba61f35674a9de4. Subsequent calls will reuse this data.
# Dataset({
#     features: ['img', 'label'],
#     num_rows: 50000
# })

# %%
# check how many labels/number of classes
num_classes = len(set(dataset_train['label']))
num_classes
# Out:
# 10

# %%
# let's view the image (it's very small)
dataset_train[0]['img']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32 at 0x1084E2BB0>

# %%
type(dataset_train[0]['img'])
# Out:
# PIL.PngImagePlugin.PngImageFile

# %% [markdown]
# Now pull in the test set (that we will use as a validation set).

# %%
dataset_val = load_dataset(
    'cifar10',
    split='test', # test dataset
    ignore_verifications=True  # set to True if seeing splits Error
)

dataset_val
# Out:
# Reusing dataset cifar10 (/Users/jamesbriggs/.cache/huggingface/datasets/cifar10/plain_text/1.0.0/447d6ec4733dddd1ce3bb577c7166b986eaa4c538dcd9e805ba61f35674a9de4)
# Dataset({
#     features: ['img', 'label'],
#     num_rows: 10000
# })

# %% [markdown]
# Most convolutional neural networks are designed so that they can only accept images of a fixed size. It's common practice to overcome this by reshaping the input images.
#
# We chose to reshape the image to 32 pixels - see ```img_size```.
#
# In addition, PyTorch uses tensors.
#
# Therefore, we will transform the data using the ```transforms.Compose``` method, and save the reshaped tensors in the ```preprocess``` variable.

# %%
# image size
img_size = 32

# preprocess variable, to be used ahead
preprocess = transforms.Compose([
    transforms.Resize((img_size,img_size)),
    transforms.ToTensor()
])

# %% [markdown]
# We can now use the ```preprocess``` variable on the dataset with the following loop. However, when we build a cnn, we should ensure every image has the same number of input channels (or depth). This is because the input dimension to the cnn cannot change.
#
# If we have RGB images, the depth will be $3$, with one channel for each color (red, green, and blue). If we have grayscale images, the depth will be $1$.
#
# In case the dataset contains images with different number of channels, we should convert them from grayscale to RGB (or the other way round). When an image is in grayscale, its ```mode``` is `L`. Otherwise, the mode is `RGB`.
#
# We then converted the images to RGB and preprocessed them in the same loop.

# %%
from tqdm.auto import tqdm

inputs_train = []

for record in tqdm(dataset_train):
    image = record['img']
    label = record['label']

    # convert from grayscale to RGB
    if image.mode == 'L':
        image = image.convert("RGB")

    # prepocessing
    input_tensor = preprocess(image)

    # append to batch list
    inputs_train.append([input_tensor, label])
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
print(len(inputs_train), inputs_train[0][0].shape)
# Out:
# 50000 torch.Size([3, 32, 32])

# %% [markdown]
# Below we can see the result from the transformation.

# %%
inputs_train[0]
# Out:
# [tensor([[[0.6980, 0.6980, 0.6980,  ..., 0.6667, 0.6588, 0.6471],
#           [0.7059, 0.7020, 0.7059,  ..., 0.6784, 0.6706, 0.6588],
#           [0.6941, 0.6941, 0.6980,  ..., 0.6706, 0.6627, 0.6549],
#           ...,
#           [0.4392, 0.4431, 0.4471,  ..., 0.3922, 0.3843, 0.3961],
#           [0.4392, 0.4392, 0.4431,  ..., 0.4000, 0.4000, 0.4000],
#           [0.4039, 0.3922, 0.4039,  ..., 0.3608, 0.3647, 0.3569]],
#
#          [[0.6902, 0.6902, 0.6902,  ..., 0.6588, 0.6510, 0.6392],
#           [0.6980, 0.6941, 0.6980,  ..., 0.6706, 0.6627, 0.6510],
#           [0.6863, 0.6863, 0.6902,  ..., 0.6627, 0.6549, 0.6471],
#           ...,
#           [0.4196, 0.4275, 0.4314,  ..., 0.3804, 0.3686, 0.3725],
#           [0.4000, 0.4039, 0.4039,  ..., 0.3725, 0.3647, 0.3608],
#           [0.3765, 0.3647, 0.3725,  ..., 0.3294, 0.3373, 0.3294]],
#
#          [[0.7412, 0.7412, 0.7412,  ..., 0.7059, 0.6941, 0.6824],
#           [0.7490, 0.7451, 0.7490,  ..., 0.7137, 0.7059, 0.6941],
#           [0.7373, 0.7373, 0.7412,  ..., 0.7059, 0.6980, 0.6902],
#           ...,
#           [0.4196, 0.4235, 0.4314,  ..., 0.3686, 0.3647, 0.3725],
#           [0.3961, 0.4000, 0.4039,  ..., 0.3647, 0.3569, 0.3569],
#           [0.3608, 0.3529, 0.3686,  ..., 0.3137, 0.3137, 0.3020]]]),
#  0]

# %% [markdown]
# The tensors are normalized to a \[0, 1\] range by the `preprocess` pipeline thanks to the `transforms.ToTensor()` function. We need to modify this normalization slightly to fit this specific dataset. To do this, we need the mean and standard deviation values for each of the RGB channels across all images.
#
# We calculate that like so:

# %%
import numpy as np

np.random.seed(0)

# calculate mean and std of images, first start by choosing a random sample of tensors
idx = np.random.randint(0, len(inputs_train), 512)
idx.shape
# Out:
# (512,)

# %%
# then we concatenate this subset of image tensors
tensors = torch.concat([inputs_train[i][0] for i in idx], axis=1)
tensors.shape
# Out:
# torch.Size([3, 16384, 32])

# %%
# merge all values into single 3-channel vector
tensors = tensors.swapaxes(0, 1).reshape(3, -1).T
tensors.shape
# Out:
# torch.Size([524288, 3])

# %%
mean = torch.mean(tensors, axis=0)
mean
# Out:
# tensor([0.4670, 0.4735, 0.4662])

# %%
std = torch.std(tensors, axis=0)
std
# Out:
# tensor([0.2496, 0.2489, 0.2521])

# %%
del tensors

# %% [markdown]
# Now we use the `mean` $[0.4670, 0.4735, 0.4662]$ and `std` $[0.2496, 0.2489, 0.2521]$ to normalize via another preprocessing step.

# %%
preprocess = transforms.Compose([transforms.Normalize(mean=mean, std=std)])

for i in tqdm(range(len(inputs_train))):
    # prepocessing
    input_tensor = preprocess(inputs_train[i][0])
    inputs_train[i][0] = input_tensor  # replace with normalized tensor
# Out:
# 100%|██████████| 50000/50000 [00:02<00:00, 21317.39it/s]

# %% [markdown]
# We can merge the preprocessing steps as follows,

# %%
# merge the two preprocessing steps from before
preprocess = transforms.Compose([
    transforms.Resize((img_size,img_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
])

# %% [markdown]
# and we can apply the same transformation to the validation set.

# %%
from tqdm.auto import tqdm

inputs_val = []
i = 0
for record in tqdm(dataset_val):
    image = record['img']
    label = record['label']

    # convert from grayscale to RBG
    if image.mode == 'L':
        image = image.convert("RGB")

    # prepocessing
    input_tensor = preprocess(image)
    inputs_val.append((input_tensor, label)) # append to batch list
# Out:
# 100%|██████████| 10000/10000 [00:05<00:00, 1837.85it/s]

# %% [markdown]
# Given the amount of data, we would improve the efficiency of our model by running it in batches. We can set the batch size to $64$.

# %%
# define batch size
batch_size = 64

# %% [markdown]
# We can then use ```DataLoader``` to split both the training and validation dataset into shuffled batches. Shuffle helps prevent model overfitting by ensuring that batches are more representative of the entire dataset.

# %%
dloader_train = torch.utils.data.DataLoader(
    inputs_train, batch_size=batch_size, shuffle=True
)

# %%
dloader_val = torch.utils.data.DataLoader(
    inputs_val, batch_size=batch_size, shuffle=False
)

# %% [markdown]
# #### Building the CNN's Structure/Architecture

# %% [markdown]
# We can now start building our cnn by generating the `ConvNeuralNet` class and the `forward` function. The `ConvNeuralNet` class defines the elements inside our network. The `forward` function establishes their order:
#
# - The first two blocks of layers are composed of a convolutional layer followed by a max-pooling layer. After each convolutional layer, we added non-linearity using the ReLU activation function.
#
# - The following two blocks of layers are composed of a convolutional layer followed by the ReLU activation function.
#
# - We then have another block composed of one convolutional layer, followed by the ReLU, followed by the max pooling layer.
#
# At each block, the images are downsampled by the max-pooling layer. Contrary, the number of channels from one layer to another increased from $3$ to $64$, to $192$, ..., to $256$. As we learned before, deeper layers have larger receptive fields and generally detect more specific and complex features, such as ears, eyes, or even human faces and dogs. The chosen filter (or kernel) size is either $3$ or $4$. This is a common choice - having a smaller filter allows the network to better generalize. Padding is $1$ pixel on each layer.
#
# - In the end, we have three fully-connected layers. The first two are activated using the ReLU, and the last one uses the Softmax.
#
# Note that we added `dropout`. It randomly zeroes (or "drops out") some of the elements of the input tensor with a probability $p = 25\%$. This has proven to be an effective technique for regularization and preventing the co-adaptation of neurons as described in the paper Improving neural networks by preventing co-adaptation of feature detectors [1].
#
#
# We can represent our network as follows:
#
# [image]

# %%
# creating a CNN class
class ConvNeuralNet(nn.Module):
	#  determine what layers and their order in CNN object
    def __init__(self, num_classes):
        super(ConvNeuralNet, self).__init__()
        self.conv_layer1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=4, padding=1)
        self.relu1 = nn.ReLU()
        self.max_pool1 = nn.MaxPool2d(kernel_size=3, stride=2)

        self.conv_layer2 = nn.Conv2d(in_channels=64, out_channels=192, kernel_size=4, padding=1)
        self.relu2 = nn.ReLU()
        self.max_pool2 = nn.MaxPool2d(kernel_size=3, stride=2)

        self.conv_layer3 = nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()

        self.conv_layer4 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()

        self.conv_layer5 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU()
        self.max_pool5 = nn.MaxPool2d(kernel_size=3, stride=2)

        self.dropout6 = nn.Dropout(p=0.5)
        self.fc6 = nn.Linear(1024, 512)
        self.relu6 = nn.ReLU()
        self.dropout7 = nn.Dropout(p=0.5)
        self.fc7 = nn.Linear(512, 256)
        self.relu7 = nn.ReLU()
        self.fc8 = nn.Linear(256, num_classes)

    # progresses data across layers
    def forward(self, x):
        out = self.conv_layer1(x)
        out = self.relu1(out)
        out = self.max_pool1(out)

        out = self.conv_layer2(out)
        out = self.relu2(out)
        out = self.max_pool2(out)

        out = self.conv_layer3(out)
        out = self.relu3(out)

        out = self.conv_layer4(out)
        out = self.relu4(out)

        out = self.conv_layer5(out)
        out = self.relu5(out)
        out = self.max_pool5(out)

        out = out.reshape(out.size(0), -1)

        out = self.dropout6(out)
        out = self.fc6(out)
        out = self.relu6(out)

        out = self.dropout7(out)
        out = self.fc7(out)
        out = self.relu7(out)

        out = self.fc8(out)  # final logits
        return out

# %% [markdown]
# After setting the architecture of our network, we can define the loss function, which is calculated after the forward propagation. We will then define the optimization methodology to run the backpropagation.
#
# The loss function used is cross-entropy.
#
# The model optimization is run using the stochastic gradient descent (SGD) method with a learning rate equal to $0.008$. Training under SGD, the network is forced to learn to extract features from the image that minimize the loss for extracting features that are the most useful for classifying or recognising images.
# The learning rate can be chosen randomly by running the model using different values and selecting the one that gives the best performance.

# %%
# set the model to device
model = ConvNeuralNet(num_classes).to(device)

# set Loss function with criterion
loss_func = nn.CrossEntropyLoss()

# set learning rate
lr = 0.008  # 0.0001

# set optimizer with optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
#total_step = len(dloader)

# %% [markdown]
# We are now ready to train our model with the forward and the backward propagation in batches. We are now using the `device` variable created above to move the data to GPU, if possible.
#
# We have set the times the learning algorithm will work through the entire training dataset (epochs) to 50. As per the learning rate, there is no rule for choosing this value. You can run the model many times with different values and choose the one with the sufficiently minimized error.
#
# It is also essential to not choose a number of `epochs` (or `lr`) that causes the model to overfit the training set. To check this, we include a pass through the validation set after each epoch, calculating the val-loss and val-accuracy. If we see the validation set performance degrades while train loss decreases, the model is likely overfitting.

# %%
# train and validate the network
num_epochs = 50
for epoch in range(num_epochs):
    model.train()
	# load in the data in batches
    for i, (images, labels) in enumerate(dloader_train):
        # move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)

        # forward propagation
        outputs = model(images)
        loss = loss_func(outputs, labels)

        # backward propagation and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # at end of epoch check validation loss and accuracy on validation set
    with torch.no_grad():
        model.eval()
        correct = 0
        total = 0
        all_val_loss = []
        for images, labels in dloader_val:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            total += labels.size(0)
            # calculate predictions
            predicted = torch.argmax(outputs, dim=1)
            # calculate actual values
            correct += (predicted == labels).sum().item()
            # calculate the loss
            all_val_loss.append(loss_func(outputs, labels).item())
        # calculate val-loss
        mean_val_loss = sum(all_val_loss) / len(all_val_loss)
        # calculate val-accuracy
        mean_val_acc = 100 * (correct / total)

    print(
        'Epoch [{}/{}], Loss: {:.4f}, Val-loss: {:.4f}, Val-acc: {:.1f}%'.format(
            epoch+1, num_epochs, loss.item(), mean_val_loss, mean_val_acc
        )
    )
# Out:
# Epoch [1/50], Loss: 2.2982, Val-loss: 2.3003, Val-acc: 11.9%
# Epoch [2/50], Loss: 2.2820, Val-loss: 2.2750, Val-acc: 15.9%
# Epoch [3/50], Loss: 1.8341, Val-loss: 2.0457, Val-acc: 19.6%
# Epoch [4/50], Loss: 1.7672, Val-loss: 1.8645, Val-acc: 24.4%
# Epoch [5/50], Loss: 2.0933, Val-loss: 1.8116, Val-acc: 28.5%
# Epoch [6/50], Loss: 1.8998, Val-loss: 1.7453, Val-acc: 33.5%
# Epoch [7/50], Loss: 1.7824, Val-loss: 1.6590, Val-acc: 37.2%
# Epoch [8/50], Loss: 2.0614, Val-loss: 1.7103, Val-acc: 36.6%
# Epoch [9/50], Loss: 1.2909, Val-loss: 1.4686, Val-acc: 44.6%
# Epoch [10/50], Loss: 1.5279, Val-loss: 1.3872, Val-acc: 48.1%
# Epoch [11/50], Loss: 1.1371, Val-loss: 1.3618, Val-acc: 48.8%
# Epoch [12/50], Loss: 2.1257, Val-loss: 2.0151, Val-acc: 33.9%
# Epoch [13/50], Loss: 0.8536, Val-loss: 1.3166, Val-acc: 52.7%
# Epoch [14/50], Loss: 1.0246, Val-loss: 1.3930, Val-acc: 51.2%
# Epoch [15/50], Loss: 0.6375, Val-loss: 1.0977, Val-acc: 60.8%
# Epoch [16/50], Loss: 0.7266, Val-loss: 1.0179, Val-acc: 63.0%
# Epoch [17/50], Loss: 0.5954, Val-loss: 1.0548, Val-acc: 62.6%
# Epoch [18/50], Loss: 0.9496, Val-loss: 1.1324, Val-acc: 62.2%
# Epoch [19/50], Loss: 0.5129, Val-loss: 0.8969, Val-acc: 68.0%
# Epoch [20/50], Loss: 1.0412, Val-loss: 0.9043, Val-acc: 67.5%
# Epoch [21/50], Loss: 0.5184, Val-loss: 1.0370, Val-acc: 64.2%
# Epoch [22/50], Loss: 0.4954, Val-loss: 0.8392, Val-acc: 70.6%
# Epoch [23/50], Loss: 0.4993, Val-loss: 0.8865, Val-acc: 70.3%
# Epoch [24/50], Loss: 0.6803, Val-loss: 0.8853, Val-acc: 70.2%
# Epoch [25/50], Loss: 0.7344, Val-loss: 1.0243, Val-acc: 66.9%
# Epoch [26/50], Loss: 0.4188, Val-loss: 0.8468, Val-acc: 72.1%
# Epoch [27/50], Loss: 0.2582, Val-loss: 0.7855, Val-acc: 74.5%
# Epoch [28/50], Loss: 1.0802, Val-loss: 0.7709, Val-acc: 74.6%
# Epoch [29/50], Loss: 0.8275, Val-loss: 1.3615, Val-acc: 62.9%
# Epoch [30/50], Loss: 0.5345, Val-loss: 0.7084, Val-acc: 76.4%
# Epoch [31/50], Loss: 0.6343, Val-loss: 0.9258, Val-acc: 70.9%
# Epoch [32/50], Loss: 0.2176, Val-loss: 1.0862, Val-acc: 70.6%
# Epoch [33/50], Loss: 0.2446, Val-loss: 0.7479, Val-acc: 77.3%
# Epoch [34/50], Loss: 0.3482, Val-loss: 1.2724, Val-acc: 67.9%
# Epoch [35/50], Loss: 0.2047, Val-loss: 0.7313, Val-acc: 78.9%
# Epoch [36/50], Loss: 0.2377, Val-loss: 0.8431, Val-acc: 76.8%
# Epoch [37/50], Loss: 0.2784, Val-loss: 0.9085, Val-acc: 76.1%
# Epoch [38/50], Loss: 0.3541, Val-loss: 1.9249, Val-acc: 64.2%
# Epoch [39/50], Loss: 0.1435, Val-loss: 0.7459, Val-acc: 78.9%
# Epoch [40/50], Loss: 0.2443, Val-loss: 0.9347, Val-acc: 76.2%
# Epoch [41/50], Loss: 0.1027, Val-loss: 1.0142, Val-acc: 75.8%
# Epoch [42/50], Loss: 0.2180, Val-loss: 1.0967, Val-acc: 75.2%
# Epoch [43/50], Loss: 0.0744, Val-loss: 0.9564, Val-acc: 77.9%
# Epoch [44/50], Loss: 0.1881, Val-loss: 0.9101, Val-acc: 78.4%
# Epoch [45/50], Loss: 0.1550, Val-loss: 1.0669, Val-acc: 76.3%
# Epoch [46/50], Loss: 0.0430, Val-loss: 0.9632, Val-acc: 78.9%
# Epoch [47/50], Loss: 0.0440, Val-loss: 0.9010, Val-acc: 80.1%
# Epoch [48/50], Loss: 0.0754, Val-loss: 1.2893, Val-acc: 75.9%
# Epoch [49/50], Loss: 0.0582, Val-loss: 1.0138, Val-acc: 79.1%
# Epoch [50/50], Loss: 0.0065, Val-loss: 1.0239, Val-acc: 79.4%

# %% [markdown]
# The network is now trained and tested! The network validation accuracy is $79.4\%$. We can go ahead and save the model to file.

# %%
torch.save(model, 'cnn.pt')

# %% [markdown]
# ---
#
# # Inference
#
# Now we will look at how to make predictions with the model. We start by loading the model from file:

# %%
import torch

model = torch.load('cnn.pt')
# switch to evaluation mode and device
model.eval().to(device)
print(device)
# Out:
# cuda

# %% [markdown]
# We will reinitialize the CIFAR-10 test set to similate a typical scenario where we would need to reload everything. Ideally we would not use the validation set as a test set.

# %%
# import CIFAR-10 dataset from HuggingFace
from datasets import load_dataset

data_test = load_dataset(
    'cifar10',
    split='test'  # test set
)
data_test
# Out:
# Reusing dataset cifar10 (/home/jupyter/.cache/huggingface/datasets/cifar10/plain_text/1.0.0/447d6ec4733dddd1ce3bb577c7166b986eaa4c538dcd9e805ba61f35674a9de4)
# Dataset({
#     features: ['img', 'label'],
#     num_rows: 10000
# })

# %%
input_tensors = []
for image in data_test['img'][:10]:
    tensor = preprocess(image)
    input_tensors.append(tensor.to(device))

# %%
# we have 10 tensors
len(input_tensors)
# Out:
# 10

# %%
# all 32x32 dimensional with 3 color channels
input_tensors[0].shape
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# We stack these into a single tensor.

# %%
# stack into a single tensor
input_tensors = torch.stack(input_tensors)
input_tensors.shape
# Out:
# torch.Size([10, 3, 32, 32])

# %%
# process through model to get output logits
outputs = model(input_tensors)
# calculate predictions
predicted = torch.argmax(outputs, dim=1)
predicted
# Out:
# tensor([5, 8, 1, 0, 6, 6, 1, 6, 3, 1], device='cuda:0')

# %%
predicted.shape
# Out:
# torch.Size([10])

# %%
# here are the class names
data_test.features['label'].names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
data_test[1]['label']
# Out:
# 8

# %%
import matplotlib.pyplot as plt

for i, image in enumerate(data_test['img'][:10]):
    plt.imshow(image)
    plt.show()
    print(data_test.features['label'].names[predicted[i]])
# Out:
# dog
# ship
# automobile
# airplane
# frog
# frog
# automobile
# frog
# cat
# automobile

# %% [markdown]
# Most of these predictions look correct, despite being very low resolution images.

# %% [markdown]
# ---
